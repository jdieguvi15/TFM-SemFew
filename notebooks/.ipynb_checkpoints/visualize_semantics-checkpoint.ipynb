# %%
# Notebook to visualize different semantincs

# %%
import torch

if torch.cuda.is_available():
    DEVICE = torch.device("cuda")
elif torch.backends.mps.is_available():
    DEVICE = torch.device("mps")
else:
    DEVICE = torch.device("cpu")

# %%
import open_clip

def encode_descriptions(class_descriptions):
    # Load CLIP
    model, _, preprocess = open_clip.create_model_and_transforms('ViT-B-32', pretrained='laion2b_s34b_b79k')
    tokenizer = open_clip.get_tokenizer('ViT-B-32')
    model = model.to(DEVICE).eval()

    # Encode the descriptions
    class_names = list(class_descriptions.keys())
    text_descriptions = list(class_descriptions.values())
    with torch.no_grad():
        text_tokens = tokenizer(text_descriptions).to(DEVICE)
        text_features = model.encode_text(text_tokens)
        text_features /= text_features.norm(dim=-1, keepdim=True)

    semantics = {class_names[i]: text_features[i] for i in range(len(class_names))}
    return semantics

# %%
import torch
import open_clip
from sklearn.metrics.pairwise import cosine_distances
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# Sentences to encode
sentences = [
    "a pear is similar to an apple",
    "a pear is different to an apple",
    "a car is similar to a bus",
    "a car is different to a bus",
    "a pear is similar to a bus",
    "a pear is different to a bus",
]

# Load CLIP model
model, _, preprocess = open_clip.create_model_and_transforms('ViT-B-32', pretrained='laion2b_s34b_b79k')
tokenizer = open_clip.get_tokenizer('ViT-B-32')

# Encode
with torch.no_grad():
    tokens = tokenizer(sentences)
    embeddings = model.encode_text(tokens)
    embeddings /= embeddings.norm(dim=-1, keepdim=True)

# t-SNE
tsne = TSNE(n_components=2, perplexity=3, random_state=42, metric='cosine')
reduced = tsne.fit_transform(embeddings.cpu().numpy())

# Plot
fig, ax = plt.subplots(figsize=(10, 6))

# Bigger points and text
for i, label in enumerate(sentences):
    x, y = reduced[i]
    ax.scatter(x, y, s=200)  # s controls marker size
    ax.text(x + 0.02, y + 0.02, label, fontsize=14)

ax.set_title("t-SNE Visualization of CLIP Sentence Embeddings", fontsize=18)
ax.grid(True)

plt.tight_layout()

# Save
fig.savefig('/Users/jdieguez/Downloads/clip_tsne_plot.png', dpi=300)

plt.show()

# %%
import seaborn as sns

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(dist_matrix, xticklabels=sentences, yticklabels=sentences, annot=True, fmt=".2f", cmap="viridis")
plt.title("Cosine Distance Matrix (CLIP Text Embeddings)")
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
import json

with open("wn_descriptions.json", 'r') as f:
    cds = json.load(f)

# %%
cds
# Out:
# {'apple': 'fruit with red or yellow or green skin and sweet to tart crisp whitish flesh',
#  'aquarium_fish': 'a tank or pool or bowl filled with water for keeping live fish and underwater animals',
#  'bear': 'massive plantigrade carnivorous or omnivorous mammals with long shaggy coats and strong claws',
#  'bee': 'any of numerous hairy-bodied insects including social and solitary species',
#  'bottle': 'a glass or plastic vessel used for storing drinks or other liquids; typically cylindrical without handles and with a narrow neck that can be plugged or capped',
#  'bowl': 'a round vessel that is open at the top; used chiefly for holding food or liquids',
#  'boy': 'a youthful male person',
#  'bridge': 'a structure that allows people or vehicles to cross an obstacle such as a river or canal or railway etc.',
#  'bus': 'a vehicle carrying many passengers; used for public transport',
#  'can': 'airtight sealed metal container for food or drink or paint etc.',
#  'castle': 'a large building formerly occupied by a ruler and fortified against attack',
#  'caterpillar': 'a wormlike and often brightly colored and hairy or spiny larva of a butterfly or moth',
#  'chair': 'a seat for one person, with a support for the back',
#  'clock': 'a timepiece that shows the time of day',
#  'cloud': 'a visible mass of water or ice particles suspended at a considerable altitude',
#  'cockroach': 'any of numerous chiefly nocturnal insects; some are domestic pests',
#  'couch': 'an upholstered seat for more than one person',
#  'cup': 'a small open container usually used for drinking; usually has a handle',
#  'dinosaur': 'any of numerous extinct terrestrial reptiles of the Mesozoic era',
#  'dolphin': 'any of various small toothed whales with a beaklike snout; larger than porpoises',
#  'elephant': 'five-toed pachyderm',
#  'forest': 'land that is covered with trees and shrubs',
#  'girl': 'a youthful female person',
#  'hamster': 'short-tailed Old World burrowing rodent with large cheek pouches',
#  'house': 'a dwelling that serves as living quarters for one or more families',
#  'kangaroo': 'any of several herbivorous leaping marsupials of Australia and New Guinea having large powerful hind legs and a long thick tail',
#  'keyboard': 'device consisting of a set of keys on a piano or organ or typewriter or typesetting machine or computer or the like',
#  'lawn_mower': 'garden tool for mowing grass on lawns',
#  'lion': 'large gregarious predatory feline of Africa and India having a tawny coat with a shaggy mane in the male',
#  'lizard': 'relatively long-bodied reptile with usually two pairs of legs and a tapering tail',
#  'lobster': 'any of several edible marine crustaceans of the families Homaridae and Nephropsidae and Palinuridae',
#  'mountain': 'a land mass that projects well above its surroundings; higher than a hill',
#  'mouse': 'any of numerous small rodents typically resembling diminutive rats having pointed snouts and small ears on elongated bodies with slender usually hairless tails',
#  'mushroom': 'fleshy body of any of numerous edible fungi',
#  'oak_tree': 'a deciduous tree of the genus Quercus; has acorns and lobed leaves',
#  'orange': 'round yellow to orange fruit of any of several citrus trees',
#  'orchid': 'any of numerous plants of the orchid family usually having flowers of unusual shapes and beautiful colors',
#  'palm_tree': 'any plant of the family Palmae having an unbranched trunk crowned by large pinnate or palmate leaves',
#  'pear': 'sweet juicy gritty-textured fruit available in many varieties',
#  'pine_tree': 'a coniferous tree',
#  'plate': 'dish on which food is served or from which food is eaten',
#  'porcupine': 'relatively large rodents with sharp erectile bristles mingled with the fur',
#  'possum': 'small furry Australian arboreal marsupials having long usually prehensile tails',
#  'rabbit': 'any of various burrowing animals of the family Leporidae having long ears and short tails; some domesticated and raised for pets or food',
#  'raccoon': 'an omnivorous nocturnal mammal native to North America and Central America',
#  'ray': 'cartilaginous fishes having horizontally flattened bodies and enlarged winglike pectoral fins with gills on the underside; most swim by moving the pectoral fins',
#  'road': 'an open way (generally public) for travel or transportation',
#  'seal': 'any of numerous marine mammals that come on shore to breed; chiefly of cold regions',
#  'shrew': 'small mouselike mammal with a long snout; related to moles',
#  'skunk': 'American musteline mammal typically ejecting an intensely malodorous fluid when startled; in some classifications put in a separate subfamily Mephitinae',
#  'skyscraper': 'a very tall building with many stories',
#  'snake': 'limbless scaly elongate reptile; some are venomous',
#  'spider': 'predatory arachnid with eight legs, two poison fangs, two feelers, and usually two silk-spinning organs at the back end of the body; they spin silk to make cocoons for eggs or traps for prey',
#  'squirrel': 'a kind of arboreal rodent having a long bushy tail',
#  'streetcar': 'a wheeled vehicle that runs on rails and is propelled by electricity',
#  'sunflower': 'any plant of the genus Helianthus having large flower heads with dark disk florets and showy yellow rays',
#  'tank': 'an enclosed armored military vehicle; has a cannon and moves on caterpillar treads',
#  'tiger': 'large feline of forests in most of Asia having a tawny coat with black stripes; endangered',
#  'train': 'public transport provided by a line of railway cars coupled together and drawn by a locomotive',
#  'trout': 'any of various game and food fishes of cool fresh waters mostly smaller than typical salmons',
#  'tulip': 'any of numerous perennial bulbous herbs having linear or broadly lanceolate leaves and usually a single showy flower',
#  'turtle': 'any of various aquatic and land reptiles having a bony shell and flipper-like limbs for swimming',
#  'willow_tree': 'any of numerous deciduous trees and shrubs of the genus Salix',
#  'wolf': 'any of various predatory carnivorous canine mammals of North America and Eurasia that usually hunt in packs',
#  'beaver': 'large semiaquatic rodent with webbed hind feet and a broad flat tail; construct complex dams and underwater lodges',
#  'beetle': 'insect having biting mouthparts and front wings modified to form horny covers overlying the membranous rear wings',
#  'butterfly': 'diurnal insect typically having a slender body with knobbed antennae and broad colorful wings',
#  'camel': 'cud-chewing mammal used as a draft or saddle animal in desert regions',
#  'cattle': 'domesticated bovine animals as a group regardless of sex or age',
#  'crab': 'decapod having eyes on short stalks and a broad flattened carapace with a small abdomen folded under the thorax and pincers',
#  'crocodile': 'large voracious aquatic reptile having a long snout with massive jaws and sharp teeth and a body covered with bony plates; of sluggish tropical waters',
#  'fox': 'alert carnivorous mammal with pointed muzzle and ears and a bushy tail; most are predators that do not hunt in packs',
#  'lamp': 'an artificial source of visible illumination',
#  'leopard': 'large feline of African and Asian forests usually having a tawny coat with black spots',
#  'man': 'an adult person who is male (as opposed to a woman)',
#  'maple_tree': 'any of numerous trees or shrubs of the genus Acer bearing winged seeds in pairs; north temperate zone',
#  'motorcycle': 'a motor vehicle with two wheels and a strong frame',
#  'plain': 'extensive tract of level open land',
#  'poppy': 'annual or biennial or perennial herbs having showy flowers',
#  'rose': 'any of many shrubs of the genus Rosa that bear roses',
#  'table': 'a piece of furniture having a smooth flat top that is usually supported by one or more vertical legs',
#  'tractor': 'a wheeled vehicle with large wheels; used in farming and other applications',
#  'woman': 'an adult female person (as opposed to a man)',
#  'baby': 'a very young child (birth to 1 year) who has not yet begun to walk or talk',
#  'bed': 'a piece of furniture that provides a place to sleep',
#  'bicycle': 'a wheeled vehicle that has two wheels and is moved by foot pedals',
#  'chimpanzee': 'intelligent somewhat arboreal ape of equatorial African forests',
#  'flatfish': 'sweet lean whitish flesh of any of numerous thin-bodied fish; usually served as thin fillets',
#  'otter': 'freshwater carnivorous mammal having webbed and clawed feet and dark brown fur',
#  'pickup_truck': 'a light truck with an open body and low sides and a tailboard',
#  'rocket': 'any vehicle self-propelled by a rocket engine',
#  'sea': 'a division of an ocean or a large body of salt water partially enclosed by land',
#  'shark': 'any of numerous elongate mostly marine carnivorous fishes with heterocercal caudal fins and tough skin covered with small toothlike scales',
#  'snail': 'freshwater or marine or terrestrial gastropod mollusk usually having an external enclosing spiral shell',
#  'sweet_pepper': 'plant bearing large mild thick-walled usually bell-shaped fruits; the principal salad peppers',
#  'telephone': 'electronic equipment that converts sound into electrical signals that can be transmitted over distances and then converts received signals back into sounds',
#  'television': 'an electronic device that receives television signals and displays them on a screen',
#  'wardrobe': 'a tall piece of furniture that provides storage space for clothes; has a door and rails or hooks for hanging clothes',
#  'whale': 'any of the larger cetacean mammals having a streamlined body and breathing through a blowhole on the head',
#  'worm': 'any of numerous relatively small elongated soft-bodied animals especially of the phyla Annelida and Chaetognatha and Nematoda and Nemertea and Platyhelminthes; also many insect larvae',
#  'organ': 'wind instrument whose sound is produced by means of pipes arranged in sets supplied with air from a bellows and controlled from a large complex musical keyboard',
#  'cocktail_shaker': 'a shaker for mixing cocktails',
#  'goose': 'web-footed long-necked typically gregarious migratory aquatic birds usually larger and less aquatic than ducks',
#  'file': 'office furniture consisting of a container for keeping papers in order',
#  'jellyfish': 'large siphonophore having a bladderlike float and stinging tentacles',
#  'missile': 'a rocket carrying a warhead of conventional or nuclear explosives; may be ballistic or directed by remote control',
#  'coral_reef': 'a reef consisting of coral consolidated into limestone',
#  'black-footed_ferret': 'musteline mammal of prairie regions of United States; nearly extinct',
#  'lipstick': 'makeup that is used to color the lips',
#  'rhinoceros_beetle': 'any of various large chiefly tropical beetles having horns on the head; pest on coconuts',
#  'stage': 'a large platform on which people can stand and can be seen by an audience',
#  'theater_curtain': 'a hanging cloth that conceals the stage from the view of the audience; rises or parts at the beginning and descends or closes between acts and at the end of a performance',
#  'Newfoundland': 'a breed of very large heavy dogs with a thick coarse usually black coat; highly intelligent dogs and vigorous swimmers; developed in Newfoundland',
#  'scoreboard': 'a large board for displaying the score of a contest (and some other information)',
#  'robin': 'small Old World songbird with a reddish breast',
#  'hotdog': 'a frankfurter served hot on a bun',
#  'upright': 'a piano with a vertical sounding board',
#  'unicycle': 'a vehicle with a single wheel that is driven by pedals',
#  'Saluki': 'old breed of tall swift keen-eyed hunting dogs resembling greyhounds; from Egypt and southwestern Asia',
#  'solar_dish': 'a concave mirror that concentrates the rays of the sun; can produce high temperatures',
#  'rock_beauty': 'gold and black butterflyfish found from West Indies to Brazil',
#  'ashcan': 'a bin that holds rubbish until it is collected',
#  'hourglass': 'a sandglass that runs for sixty minutes',
#  'white_wolf': 'wolf of Arctic North America having white fur and a black-tipped tail',
#  'horizontal_bar': 'gymnastic apparatus consisting of a bar supported in a horizontal position by uprights at both ends',
#  'three-toed_sloth': 'a sloth that has three long claws on each forefoot and each hindfoot',
#  'prayer_rug': 'a small rug used by Muslims during their devotions',
#  'toucan': 'brilliantly colored arboreal fruit-eating bird of tropical America having a very large thin-walled beak',
#  'combination_lock': 'lock that can be opened only by turning dials in a special sequence',
#  'garbage_truck': 'a truck for collecting domestic refuse',
#  'malamute': 'breed of sled dog developed in Alaska',
#  'mixing_bowl': 'bowl used with an electric mixer',
#  'house_finch': 'small finch originally of the western United States and Mexico',
#  'reel': 'winder consisting of a revolving spool with a handle; attached to a fishing rod',
#  'triceratops': 'huge ceratopsian dinosaur having three horns and the neck heavily armored with a very solid frill',
#  'consomme': 'clear soup usually of beef or veal or chicken',
#  'miniature_poodle': 'a breed of small poodles',
#  'nematode': 'unsegmented worms with elongated rounded body pointed at both ends; mostly free-living but some are parasitic',
#  'carton': 'a box made of cardboard; opens by flaps on top',
#  'golden_retriever': 'an English breed having a long silky golden coat',
#  'poncho': 'a blanket-like cloak with a hole in the center for the head',
#  'miniskirt': 'a very short skirt',
#  'king_crab': 'large edible crab of northern Pacific waters especially along the coasts of Alaska and Japan',
#  'meerkat': 'a mongoose-like viverrine of South Africa having a face like a lemur and only four toes',
#  'electric_guitar': 'a guitar whose sound is amplified by electrical means',
#  'wok': 'pan with a convex bottom; used for frying in Chinese cooking',
#  'dalmatian': 'a large breed having a smooth white coat with black or brown spots; originated in Dalmatia',
#  'tile_roof': 'a roof made of fired clay tiles',
#  'ladybug': 'small round bright-colored and spotted beetle that usually feeds on aphids and other insect pests',
#  'parallel_bars': 'gymnastic apparatus consisting of two parallel wooden rods supported on uprights',
#  'catamaran': 'a sailboat with two parallel hulls held together by single deck',
#  'green_mamba': 'green phase of the black mamba',
#  'dome': 'a hemispherical roof',
#  'dugong': 'sirenian tusked mammal found from eastern Africa to Australia; the flat tail is bilobate',
#  'tobacco_shop': 'a shop that sells pipes and pipe tobacco and cigars and cigarettes',
#  'Gordon_setter': 'a Scottish breed with a black-and-tan coat',
#  'pencil_box': 'a box for holding pencils',
#  'street_sign': 'a sign visible from the street',
#  'barrel': 'a cylindrical container that holds liquids',
#  'fire_screen': 'a metal screen before an open fire for protection (especially against flying sparks)',
#  'yawl': "a ship's small boat (usually rowed by 4 or 6 oars)",
#  'Walker_hound': 'an American breed of foxhound',
#  'boxer': 'a breed of stocky medium-sized short-haired dog with a brindled coat and square-jawed muzzle developed in Germany',
#  'photocopier': 'a copier that uses photographic methods of making copies',
#  'cuirass': 'medieval body armor that covers the chest and back',
#  'slot': 'a slot machine that is used for gambling',
#  'harvestman': 'spiderlike arachnid with a small rounded body and very long thin legs',
#  'clog': 'footwear usually with wooden soles',
#  'bookshop': 'a shop where books are sold',
#  'frying_pan': 'a pan used for frying foods',
#  'crate': 'a rugged box (usually made of wood); used for shipping',
#  'aircraft_carrier': 'a large warship that carries planes and has a long flat deck for takeoffs and landings',
#  'chime': 'a percussion instrument consisting of a set of tuned bells that are struck with a hammer; used as an orchestral instrument',
#  'Ibizan_hound': 'breed of slender agile medium-sized hound found chiefly in the Balearic Islands; said to have been bred originally by the Pharaohs of ancient Egypt',
#  'dishrag': 'a cloth for washing dishes',
#  'iPod': '(trademark) a pocket-sized device used to play music files',
#  'holster': 'a sheath (usually leather) for carrying a handgun',
#  'worm_fence': 'rail fence consisting of a zigzag of interlocking rails',
#  'ear': 'the externally visible cartilaginous structure of the external ear',
#  'vase': 'an open jar of glass or porcelain used as an ornament or to hold flowers',
#  'beer_bottle': 'a bottle that holds beer',
#  'spider_web': 'a web spun by spiders to trap insect prey',
#  'komondor': 'Hungarian breed of large powerful shaggy-coated white dog; used also as guard dog',
#  'bolete': 'any fungus of the family Boletaceae',
#  'trifle': 'a cold pudding made of layers of sponge cake spread with fruit or jelly; may be decorated with nuts, cream, or chocolate',
#  'African_hunting_dog': 'a powerful doglike mammal of southern and eastern Africa that hunts in large packs; now rare in settled area',
#  'cliff': 'a steep high face of rock',
#  'oboe': 'a slender double-reed instrument; a woodwind with a conical bore and a double-reed mouthpiece',
#  'carousel': 'a large, rotating machine with seats for children to ride or amusement',
#  'cannon': 'a large artillery gun that is usually on wheels',
#  'French_bulldog': 'small stocky version of the bulldog having a sleek coat and square head',
#  'school_bus': 'a bus used to transport children to or from school',
#  'Tibetan_mastiff': 'very large powerful rough-coated dog native to central Asia',
#  'snorkel': "breathing device consisting of a bent tube fitting into a swimmer's mouth and extending above the surface; allows swimmer to breathe while face down in the water",
#  'ant': 'social insect living in organized colonies; characteristically the males and fertile queen have wings during breeding season; wingless sterile females are the workers',
#  'hair_slide': 'a decorative hinged clip that girls and women put in their hair to hold it in place',
#  'Arctic_fox': 'thickly-furred fox of Arctic regions; brownish in summer and white in winter'}

# %%
default_path = "/Users/jdieguez/Documents/master/TFM/code/TFM-SemFew/Model/semantic/cifar100_semantic_clip_gpt.pth"
semantic = torch.load(default_path, map_location=DEVICE)['semantic_feature']
semantic = {k: v.float() for k, v in semantic.items()}

# %%
semantic['train'].shape
# Out:
# torch.Size([512])

# %%
import torch
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

def visualize(encodings, title="2D Visualization"):
    # Convert to a matrix
    class_names = list(encodings.keys())
    vectors = torch.stack([encodings[cls] for cls in class_names])
    
    # Apply t-SNE
    tsne = TSNE(n_components=2, random_state=42, perplexity=30, init='pca')
    vectors_2d = tsne.fit_transform(vectors.cpu().numpy())
    
    # Plot
    plt.figure(figsize=(12, 10))
    for i, label in enumerate(class_names):
        x, y = vectors_2d[i]
        plt.scatter(x, y)
        plt.text(x + 0.3, y + 0.3, label, fontsize=8)
    
    plt.title(title)
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
visualize(semantic)

# %%
import torch
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.spatial.distance import pdist, squareform
from scipy.stats import entropy

# Interclass entropy with distances
def interclass_entropy(class_encodings, metric='cosine'):
    dists = pdist(class_encodings.cpu().numpy(), metric=metric)
    prob = dists / dists.sum()
    return entropy(prob)

# Interclass entropy based on histogram (focuses more on the shape)
def interclass_entropy_histogram(class_encodings, metric='cosine', bins=50):
    dists = pdist(class_encodings.cpu().numpy(), metric=metric)
    hist, _ = np.histogram(dists, bins=bins, density=True)
    hist += 1e-9  # prevent log(0)
    return entropy(hist, base=2)

# %%
def analyze_class_distances(embeddings_dict, k=10, metric='cosine', show=True):
    class_names = list(embeddings_dict.keys())
    encodings = torch.stack([embeddings_dict[cls] for cls in class_names])

    distances = pdist(encodings.cpu().numpy(), metric=metric)
    distance_matrix = squareform(distances)

    # Global statistics
    finite_distances = distances[np.isfinite(distances)]  # safety check
    min_dist = np.min(finite_distances)
    max_dist = np.max(finite_distances)
    mean_dist = np.mean(finite_distances)
    print(f" * Min distance:  {min_dist:.4f}")
    print(f" * Max distance:  {max_dist:.4f}")
    print(f" * Mean distance: {mean_dist:.4f}")

    df = pd.DataFrame(distance_matrix, index=class_names, columns=class_names)

    # Calculate Top k most similar embeddings
    np.fill_diagonal(distance_matrix, np.nan)  # ignore self-distances
    triu_indices = np.triu_indices_from(distance_matrix, k=1)
    sorted_indices = np.argsort(distance_matrix[triu_indices])
    
    top_k_pairs = [(class_names[i], class_names[j], distance_matrix[i, j])
                    for i, j in zip(triu_indices[0][sorted_indices[:k]],
                                    triu_indices[1][sorted_indices[:k]])]

    print("🔍 Top k Most Similar Classes:")
    for a, b, d in top_k_pairs:
        print(f" - {a} ↔ {b}: {d:.4f}")

    if show:
        # Plot heatmap
        plt.figure(figsize=(20, 16))
        sns.heatmap(df, cmap="viridis", xticklabels=True, yticklabels=True)
        plt.title(f'Pairwise {metric.capitalize()} Distances Between Class Encodings')
        plt.xlabel('Class')
        plt.ylabel('Class')
        plt.tight_layout()
        plt.show()

    return df

# %%
df = analyze_class_distances(semantic)
# Out:
#  * Min distance:  0.0202
#  * Max distance:  0.2911
#  * Mean distance: 0.1453
# 🔍 Top k Most Similar Classes:
#  - girl ↔ woman: 0.0202
#  - dolphin ↔ whale: 0.0368
#  - snake ↔ lizard: 0.0373
#  - man ↔ woman: 0.0391
#  - wolf ↔ fox: 0.0404
#  - squirrel ↔ hamster: 0.0408
#  - bear ↔ hamster: 0.0413
#  - bear ↔ rabbit: 0.0422
#  - bus ↔ streetcar: 0.0425
#  - bear ↔ cattle: 0.0429

# %%
import torch
import numpy as np
from scipy.spatial.distance import pdist
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
import matplotlib.pyplot as plt

def cluster_classes(embeddings_dict, metric='cosine', num_clusters=None, distance_threshold=None):
    class_names = list(embeddings_dict.keys())
    encodings = torch.stack([embeddings_dict[cls] for cls in class_names]).cpu().numpy()

    # Pairwise distances
    pairwise_dist = pdist(encodings, metric=metric)

    # Linkage matrix
    Z = linkage(pairwise_dist, method='average')  # Other methods: 'ward', 'single', 'complete'

    # Cluster them with different methods
    if num_clusters:
        clusters = fcluster(Z, t=num_clusters, criterion='maxclust')
    elif distance_threshold:
        clusters = fcluster(Z, t=distance_threshold, criterion='distance')
    else:
        clusters = None  # No cutting, only dendrogram

    # Plot dendrogram
    plt.figure(figsize=(12, 6))
    dendrogram(Z, labels=class_names, leaf_rotation=90)
    plt.title(f'Hierarchical Clustering of Classes ({metric} distance)')
    plt.xlabel('Class')
    plt.ylabel('Distance')
    plt.tight_layout()
    plt.show()

    # Print clusters
    if clusters is not None:
        from collections import defaultdict
        cluster_groups = defaultdict(list)
        for cls, cluster_id in zip(class_names, clusters):
            cluster_groups[cluster_id].append(cls)

        print("🔍 Clustered Classes:")
        for cluster_id, members in sorted(cluster_groups.items()):
            print(f" - Cluster {cluster_id}: {members}")

        return cluster_groups

    return Z  # return linkage matrix if clusters not formed yet

# %%
clusters = cluster_classes(semantic, distance_threshold=0.14)
# Out:
# 🔍 Clustered Classes:
#  - Cluster 1: ['sunflower', 'tulip', 'orchid', 'poppy', 'rose']
#  - Cluster 2: ['castle', 'bridge']
#  - Cluster 3: ['forest', 'pine_tree', 'oak_tree', 'willow_tree', 'palm_tree', 'maple_tree']
#  - Cluster 4: ['orange', 'pear', 'apple', 'mushroom', 'sweet_pepper']
#  - Cluster 5: ['skyscraper', 'turtle', 'spider', 'girl', 'seal', 'elephant', 'possum', 'squirrel', 'plate', 'wolf', 'road', 'mouse', 'boy', 'shrew', 'tiger', 'caterpillar', 'lion', 'dolphin', 'cockroach', 'bear', 'porcupine', 'bee', 'hamster', 'lobster', 'bowl', 'can', 'bottle', 'trout', 'snake', 'skunk', 'lizard', 'cup', 'kangaroo', 'dinosaur', 'rabbit', 'ray', 'mountain', 'house', 'baby', 'chimpanzee', 'fox', 'leopard', 'man', 'plain', 'rocket', 'snail', 'wardrobe', 'whale', 'woman', 'worm', 'otter', 'crocodile', 'shark', 'butterfly', 'beaver', 'beetle', 'flatfish', 'camel', 'crab', 'sea', 'cattle']
#  - Cluster 6: ['keyboard', 'telephone', 'television']
#  - Cluster 7: ['train', 'bus', 'chair', 'tank', 'couch', 'streetcar', 'lawn_mower', 'bed', 'bicycle', 'pickup_truck', 'table', 'motorcycle', 'tractor']
#  - Cluster 8: ['lamp']
#  - Cluster 9: ['raccoon']
#  - Cluster 10: ['cloud']
#  - Cluster 11: ['clock']
#  - Cluster 12: ['aquarium_fish']

# %%
import torch
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import pairwise_distances_argmin_min

def cluster_classes_kmeans(embeddings_dict, n_clusters=10, metric='cosine'):
    class_names = list(embeddings_dict.keys())
    class_encodings = torch.stack([embeddings_dict[cls] for cls in class_names])
    
    # Normalize encodings for cosine similarity
    norm_encodings = torch.nn.functional.normalize(class_encodings, dim=1)
    
    # KMeans with uses Euclidean distance but normalized
    kmeans = KMeans(n_clusters=n_clusters, random_state=42, n_init="auto")
    labels = kmeans.fit_predict(norm_encodings.cpu().numpy())

    # Group class names by cluster label
    clustered_classes = {}
    for idx, cluster_id in enumerate(labels):
        clustered_classes.setdefault(cluster_id, []).append(class_names[idx])

    # Cluster summary
    for cluster_id, class_list in clustered_classes.items():
        print(f"Cluster {cluster_id} ({len(class_list)} classes): {class_list}")

    return clustered_classes

# %%
clusters = cluster_classes_kmeans(semantic)
# Out:
# Cluster 2 (7 classes): ['train', 'bus', 'chair', 'streetcar', 'bicycle', 'pickup_truck', 'tractor']
# Cluster 1 (15 classes): ['skyscraper', 'castle', 'keyboard', 'tank', 'road', 'couch', 'lawn_mower', 'bridge', 'mountain', 'house', 'bed', 'plain', 'rocket', 'wardrobe', 'motorcycle']
# Cluster 6 (11 classes): ['turtle', 'seal', 'dolphin', 'trout', 'whale', 'otter', 'crocodile', 'shark', 'beaver', 'sea', 'aquarium_fish']
# Cluster 0 (29 classes): ['raccoon', 'girl', 'elephant', 'mushroom', 'possum', 'squirrel', 'wolf', 'mouse', 'boy', 'shrew', 'tiger', 'lion', 'bear', 'porcupine', 'hamster', 'snake', 'skunk', 'lizard', 'kangaroo', 'dinosaur', 'rabbit', 'baby', 'chimpanzee', 'fox', 'leopard', 'man', 'woman', 'camel', 'cattle']
# Cluster 5 (8 classes): ['spider', 'caterpillar', 'cockroach', 'bee', 'snail', 'worm', 'butterfly', 'beetle']
# Cluster 7 (7 classes): ['orange', 'forest', 'pine_tree', 'oak_tree', 'willow_tree', 'palm_tree', 'maple_tree']
# Cluster 4 (13 classes): ['clock', 'pear', 'apple', 'plate', 'bowl', 'can', 'bottle', 'cup', 'sweet_pepper', 'table', 'telephone', 'television', 'lamp']
# Cluster 3 (5 classes): ['sunflower', 'tulip', 'orchid', 'poppy', 'rose']
# Cluster 9 (4 classes): ['lobster', 'ray', 'flatfish', 'crab']
# Cluster 8 (1 classes): ['cloud']

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

def plot_kmeans(embeddings_dict, n_clusters=10, normalize=True, title="KMeans Clusters in 2D Space"):
    class_names = list(embeddings_dict.keys())
    class_encodings = torch.stack([embeddings_dict[cls] for cls in class_names])
    
    if normalize:
        class_encodings = torch.nn.functional.normalize(class_encodings, dim=1)

    # KMeans clustering
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    cluster_labels = kmeans.fit_predict(class_encodings.cpu().numpy())

    # Reduce to 2D
    #pca = PCA(n_components=2)
    #reduced = pca.fit_transform(class_encodings.cpu().numpy())
    reduced = TSNE(n_components=2).fit_transform(class_encodings.cpu().numpy())

    # Plot
    plt.figure(figsize=(10, 7))
    scatter = plt.scatter(reduced[:, 0], reduced[:, 1], c=cluster_labels, cmap='tab10', s=60)#, edgecolors='k')

    for i, name in enumerate(class_names):
        plt.text(reduced[i, 0], reduced[i, 1], name, fontsize=8, alpha=0.6)
    plt.title(title)
    plt.colorbar(scatter, label="Cluster ID")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    for cluster_id, names in sorted(clusters.items()):
        print(f"Cluster {cluster_id}: {', '.join(names)}")

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

def plot_selected_classes(embeddings_dict, selected_classes, normalize=True, title="Selected Class Embeddings (2D)"):
    # Filter embeddings
    filtered_names = [cls for cls in selected_classes if cls in embeddings_dict]
    if not filtered_names:
        print("No selected classes found in the dictionary.")
        return

    filtered_encodings = torch.stack([embeddings_dict[cls] for cls in filtered_names])

    if normalize:
        filtered_encodings = torch.nn.functional.normalize(filtered_encodings, dim=1)

    # Reduce to 2D using t-SNE
    reduced = TSNE(n_components=2, perplexity=3, random_state=42).fit_transform(filtered_encodings.cpu().numpy())

    # Plot
    fig, ax = plt.subplots(figsize=(10, 8))
    ax.scatter(reduced[:, 0], reduced[:, 1], s=120, c='royalblue', edgecolors='black', zorder=3)

    for i, name in enumerate(filtered_names):
        ax.annotate(
            name,
            xy=(reduced[i, 0], reduced[i, 1]),
            xytext=(5, 5),  # Offset text slightly
            textcoords="offset points",
            fontsize=11,
            ha='left',
            va='bottom',
            color='black',
            bbox=dict(facecolor='white', alpha=0.6, edgecolor='none', boxstyle='round,pad=0.2'),
            zorder=4
        )

    ax.set_title(title, fontsize=16)
    ax.grid(True)
    plt.tight_layout()
    plt.show()
    fig.savefig(f'/Users/jdieguez/Downloads/{title}.png'.replace(" ", "_"))

# %%
plot_kmeans(semantic)
# Out:
# Cluster 0: oak_tree, palm_tree, pine_tree, willow_tree, maple_tree
# Cluster 1: clock, keyboard, tulip, television, telephone
# Cluster 2: apple, bear, boy, bridge, can, caterpillar, cloud, girl, mountain, orange, ray, snake, tank, sea, shark, baby, fox, man, plain, rocket, rose
# Cluster 3: aquarium_fish, cockroach, lobster, turtle, crab, crocodile, flatfish
# Cluster 4: dinosaur, dolphin, elephant, lion, mushroom, rabbit, seal, tiger, wolf, camel, cattle, chimpanzee, leopard, whale
# Cluster 5: forest, hamster, kangaroo, lizard, mouse, porcupine, possum, raccoon, shrew, skunk, squirrel, trout, beaver, otter, snail
# Cluster 6: pear
# Cluster 7: bee, orchid, spider, sunflower, beetle, butterfly, poppy, sweet_pepper, worm
# Cluster 8: bottle, bowl, bus, castle, couch, cup, house, lawn_mower, road, skyscraper, streetcar, train, motorcycle, tractor, bed, bicycle, pickup_truck, wardrobe, woman
# Cluster 9: chair, plate, lamp, table

# %%
from scipy.spatial.distance import cdist

def find_k_similar(embeddings_dict, k=5, metric='cosine'):
    class_names = list(embeddings_dict.keys())
    embeddings = torch.stack([embeddings_dict[cls] for cls in class_names])
    
    embeddings = torch.nn.functional.normalize(embeddings, dim=1)
    distances = cdist(embeddings.cpu().numpy(), embeddings.cpu().numpy(), metric=metric)
    
    top_k_dict = {}
    for i, cls in enumerate(class_names):
        sim_indices = np.argsort(distances[i]) 
        top_indices = [j for j in sim_indices if j != i][:k]  # exclude self
        top_k_dict[cls] = [class_names[j] for j in top_indices]

    return top_k_dict

# %%
similars_dict = find_k_similar(semantic)
similars_dict
# Out:
# {'train': ['streetcar', 'bus', 'tractor', 'house', 'tank'],
#  'skyscraper': ['house', 'plain', 'mountain', 'castle', 'road'],
#  'turtle': ['lizard', 'seal', 'crocodile', 'snake', 'whale'],
#  'raccoon': ['possum', 'skunk', 'squirrel', 'wolf', 'fox'],
#  'spider': ['butterfly', 'cockroach', 'beetle', 'snake', 'bee'],
#  'orange': ['apple', 'pear', 'sweet_pepper', 'oak_tree', 'hamster'],
#  'castle': ['skyscraper', 'house', 'mountain', 'plain', 'road'],
#  'keyboard': ['telephone', 'television', 'train', 'tank', 'couch'],
#  'clock': ['television', 'telephone', 'man', 'keyboard', 'plate'],
#  'pear': ['apple', 'hamster', 'cup', 'plate', 'baby'],
#  'girl': ['woman', 'man', 'baby', 'hamster', 'bear'],
#  'seal': ['whale', 'otter', 'bear', 'dolphin', 'hamster'],
#  'elephant': ['bear', 'cattle', 'camel', 'rabbit', 'hamster'],
#  'apple': ['pear', 'orange', 'sweet_pepper', 'hamster', 'plate'],
#  'bus': ['streetcar', 'train', 'tractor', 'pickup_truck', 'tank'],
#  'mushroom': ['snail', 'hamster', 'bear', 'pear', 'beetle'],
#  'possum': ['squirrel', 'hamster', 'shrew', 'mouse', 'skunk'],
#  'squirrel': ['hamster', 'possum', 'bear', 'skunk', 'rabbit'],
#  'chair': ['couch', 'table', 'cup', 'bus', 'tractor'],
#  'tank': ['tractor', 'train', 'rocket', 'motorcycle', 'bear'],
#  'plate': ['cup', 'bowl', 'hamster', 'table', 'pear'],
#  'wolf': ['fox', 'bear', 'skunk', 'rabbit', 'squirrel'],
#  'road': ['plain', 'mountain', 'house', 'train', 'skyscraper'],
#  'mouse': ['shrew', 'hamster', 'possum', 'rabbit', 'squirrel'],
#  'boy': ['man', 'girl', 'baby', 'woman', 'bear'],
#  'shrew': ['hamster', 'bear', 'mouse', 'possum', 'squirrel'],
#  'couch': ['chair', 'table', 'house', 'bed', 'hamster'],
#  'sunflower': ['rose', 'tulip', 'poppy', 'orchid', 'bee'],
#  'tiger': ['leopard', 'bear', 'lion', 'fox', 'snake'],
#  'caterpillar': ['worm', 'bee', 'butterfly', 'beetle', 'snake'],
#  'lion': ['bear', 'camel', 'tiger', 'leopard', 'fox'],
#  'streetcar': ['bus', 'train', 'tractor', 'pickup_truck', 'tank'],
#  'lawn_mower': ['tractor', 'motorcycle', 'tank', 'train', 'house'],
#  'tulip': ['rose', 'poppy', 'orchid', 'palm_tree', 'sunflower'],
#  'forest': ['oak_tree', 'palm_tree', 'mountain', 'pine_tree', 'plain'],
#  'dolphin': ['whale', 'shark', 'seal', 'turtle', 'ray'],
#  'cockroach': ['beetle', 'lizard', 'lobster', 'snake', 'hamster'],
#  'bear': ['hamster', 'rabbit', 'cattle', 'wolf', 'fox'],
#  'porcupine': ['skunk', 'hamster', 'bear', 'squirrel', 'cockroach'],
#  'bee': ['beetle', 'butterfly', 'caterpillar', 'cockroach', 'crab'],
#  'hamster': ['squirrel', 'bear', 'rabbit', 'shrew', 'skunk'],
#  'lobster': ['crab', 'cockroach', 'beetle', 'lizard', 'bear'],
#  'bowl': ['cup', 'plate', 'pear', 'table', 'can'],
#  'can': ['cup', 'bottle', 'plate', 'pear', 'bowl'],
#  'bottle': ['cup', 'can', 'bowl', 'plate', 'pear'],
#  'trout': ['flatfish', 'whale', 'shark', 'lizard', 'crocodile'],
#  'snake': ['lizard', 'bear', 'hamster', 'worm', 'cockroach'],
#  'bridge': ['road', 'train', 'castle', 'skyscraper', 'mountain'],
#  'pine_tree': ['palm_tree', 'oak_tree', 'maple_tree', 'willow_tree', 'forest'],
#  'skunk': ['hamster', 'squirrel', 'bear', 'fox', 'wolf'],
#  'lizard': ['snake', 'dinosaur', 'cockroach', 'lobster', 'turtle'],
#  'cup': ['bottle', 'can', 'bowl', 'plate', 'pear'],
#  'kangaroo': ['fox', 'squirrel', 'rabbit', 'possum', 'bear'],
#  'oak_tree': ['palm_tree', 'willow_tree', 'maple_tree', 'pine_tree', 'pear'],
#  'dinosaur': ['lizard', 'bear', 'snake', 'cattle', 'cockroach'],
#  'rabbit': ['bear', 'hamster', 'squirrel', 'fox', 'cattle'],
#  'orchid': ['rose', 'tulip', 'palm_tree', 'poppy', 'butterfly'],
#  'willow_tree': ['oak_tree', 'palm_tree', 'pine_tree', 'squirrel', 'plain'],
#  'ray': ['flatfish', 'shark', 'whale', 'dolphin', 'crocodile'],
#  'palm_tree': ['oak_tree', 'pine_tree', 'willow_tree', 'forest', 'plain'],
#  'mountain': ['plain', 'road', 'bear', 'sea', 'snake'],
#  'house': ['wardrobe', 'skyscraper', 'plain', 'train', 'road'],
#  'cloud': ['mountain', 'sea', 'plain', 'rocket', 'bear'],
#  'baby': ['hamster', 'girl', 'woman', 'bear', 'snake'],
#  'bed': ['couch', 'wardrobe', 'table', 'television', 'house'],
#  'bicycle': ['motorcycle', 'tractor', 'streetcar', 'lawn_mower', 'bus'],
#  'chimpanzee': ['bear', 'cattle', 'hamster', 'elephant', 'wolf'],
#  'fox': ['wolf', 'bear', 'squirrel', 'rabbit', 'skunk'],
#  'leopard': ['tiger', 'bear', 'snake', 'hamster', 'squirrel'],
#  'man': ['woman', 'girl', 'boy', 'bear', 'baby'],
#  'pickup_truck': ['bus', 'tractor', 'streetcar', 'train', 'tank'],
#  'plain': ['mountain', 'road', 'house', 'bear', 'hamster'],
#  'poppy': ['rose', 'tulip', 'orchid', 'sunflower', 'sweet_pepper'],
#  'rocket': ['tank', 'cup', 'hamster', 'whale', 'beetle'],
#  'rose': ['tulip', 'poppy', 'orchid', 'pear', 'apple'],
#  'snail': ['worm', 'snake', 'caterpillar', 'cockroach', 'turtle'],
#  'sweet_pepper': ['pear', 'apple', 'beetle', 'bear', 'rabbit'],
#  'table': ['couch', 'cup', 'plate', 'chair', 'wardrobe'],
#  'telephone': ['television', 'keyboard', 'plate', 'cup', 'woman'],
#  'wardrobe': ['house', 'couch', 'train', 'table', 'television'],
#  'whale': ['dolphin', 'shark', 'seal', 'ray', 'otter'],
#  'woman': ['girl', 'man', 'baby', 'hamster', 'bear'],
#  'worm': ['caterpillar', 'snake', 'cockroach', 'snail', 'lizard'],
#  'otter': ['beaver', 'seal', 'bear', 'whale', 'squirrel'],
#  'motorcycle': ['bicycle', 'tractor', 'lawn_mower', 'tank', 'rocket'],
#  'television': ['telephone', 'couch', 'plate', 'house', 'wardrobe'],
#  'lamp': ['cup', 'table', 'television', 'bottle', 'plate'],
#  'crocodile': ['snake', 'lizard', 'dinosaur', 'turtle', 'lobster'],
#  'shark': ['whale', 'dolphin', 'ray', 'seal', 'flatfish'],
#  'butterfly': ['beetle', 'bee', 'cockroach', 'caterpillar', 'lizard'],
#  'beaver': ['otter', 'bear', 'seal', 'crocodile', 'squirrel'],
#  'beetle': ['cockroach', 'butterfly', 'bee', 'lobster', 'crab'],
#  'tractor': ['tank', 'motorcycle', 'bicycle', 'train', 'lawn_mower'],
#  'flatfish': ['ray', 'whale', 'shark', 'turtle', 'trout'],
#  'maple_tree': ['oak_tree', 'pine_tree', 'palm_tree', 'willow_tree', 'forest'],
#  'camel': ['bear', 'cattle', 'elephant', 'rabbit', 'hamster'],
#  'crab': ['lobster', 'beetle', 'cockroach', 'bee', 'butterfly'],
#  'sea': ['mountain', 'plain', 'seal', 'whale', 'crocodile'],
#  'cattle': ['bear', 'hamster', 'rabbit', 'camel', 'wolf'],
#  'aquarium_fish': ['flatfish', 'trout', 'shark', 'ray', 'whale']}

# %%
with open("most_confused.json", "w") as f:
    json.dump(similars_dict, f, indent=2)

# %%
def study_semantics(semantic, title):
    print("Model: ", title)
    class_names = list(semantic.keys())
    embeddings = torch.stack([semantic[cls] for cls in class_names])
    print(f"Interclass entropy: {interclass_entropy(embeddings)}")
    print(f"Histogram interclass entropy: {interclass_entropy_histogram(embeddings)}")
    plot_kmeans(semantic, title=title)
    #selected_classes = ["boy", "man", "woman", "baby", "girl"]
    #plot_selected_classes(semantic, selected_classes, title=title+" focused")
    
    analyze_class_distances(semantic, show=False)

# %%
# Default

default_path = "/Users/jdieguez/Documents/master/TFM/code/TFM-SemFew/Model/semantic/cifar100_semantic_clip_gpt.pth"
semantic = torch.load(default_path, map_location=DEVICE)['semantic_feature']
semantic = {k: v.float() for k, v in semantic.items()}

study_semantics(semantic, "Default")
# Out:
# Model:  Default
# Interclass entropy: 8.46810501578651
# Histogram interclass entropy: 4.92467459531826
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.0202
#  * Max distance:  0.2911
#  * Mean distance: 0.1453
# 🔍 Top k Most Similar Classes:
#  - girl ↔ woman: 0.0202
#  - dolphin ↔ whale: 0.0368
#  - snake ↔ lizard: 0.0373
#  - man ↔ woman: 0.0391
#  - wolf ↔ fox: 0.0404
#  - squirrel ↔ hamster: 0.0408
#  - bear ↔ hamster: 0.0413
#  - bear ↔ rabbit: 0.0422
#  - bus ↔ streetcar: 0.0425
#  - bear ↔ cattle: 0.0429

# %%
# With names
class_names = ['apple', 'aquarium_fish', 'bear', 'bee', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'can', 'castle', 'caterpillar', 'chair', 'clock', 'cloud', 'cockroach', 'couch', 'cup', 'dinosaur', 'dolphin', 'elephant', 'forest', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard', 'lawn_mower', 'lion', 'lizard', 'lobster', 'mountain', 'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid', 'palm_tree', 'pear', 'pine_tree', 'plate', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 'seal', 'shrew', 'skunk', 'skyscraper', 'snake', 'spider', 'squirrel', 'streetcar', 'sunflower', 'tank', 'tiger', 'train', 'trout', 'tulip', 'turtle', 'willow_tree', 'wolf', 'beaver', 'beetle', 'butterfly', 'camel', 'cattle', 'crab', 'crocodile', 'flatfish', 'lamp', 'maple_tree', 'motorcycle', 'otter', 'sea', 'shark', 'television', 'tractor', 'baby', 'bed', 'bicycle', 'chimpanzee', 'fox', 'leopard', 'man', 'pickup_truck', 'plain', 'poppy', 'rocket', 'rose', 'snail', 'sweet_pepper', 'table', 'telephone', 'wardrobe', 'whale', 'woman', 'worm']
class_descriptions = {cls:cls for cls in class_names}
semantic = encode_descriptions(class_descriptions)
study_semantics(semantic, "Just names")
# Out:
# Model:  Just names
# Interclass entropy: 8.477072437739844
# Histogram interclass entropy: 4.9770559557881855
# Cluster 0: oak_tree, palm_tree, pine_tree, willow_tree, maple_tree
# Cluster 1: clock, keyboard, tulip, television, telephone
# Cluster 2: apple, bear, boy, bridge, can, caterpillar, cloud, girl, mountain, orange, ray, snake, tank, sea, shark, baby, fox, man, plain, rocket, rose
# Cluster 3: aquarium_fish, cockroach, lobster, turtle, crab, crocodile, flatfish
# Cluster 4: dinosaur, dolphin, elephant, lion, mushroom, rabbit, seal, tiger, wolf, camel, cattle, chimpanzee, leopard, whale
# Cluster 5: forest, hamster, kangaroo, lizard, mouse, porcupine, possum, raccoon, shrew, skunk, squirrel, trout, beaver, otter, snail
# Cluster 6: pear
# Cluster 7: bee, orchid, spider, sunflower, beetle, butterfly, poppy, sweet_pepper, worm
# Cluster 8: bottle, bowl, bus, castle, couch, cup, house, lawn_mower, road, skyscraper, streetcar, train, motorcycle, tractor, bed, bicycle, pickup_truck, wardrobe, woman
# Cluster 9: chair, plate, lamp, table
#  * Min distance:  0.0958
#  * Max distance:  0.6316
#  * Mean distance: 0.3428
# 🔍 Top k Most Similar Classes:
#  - man ↔ plain: 0.0958
#  - boy ↔ girl: 0.1032
#  - boy ↔ man: 0.1043
#  - cloud ↔ mountain: 0.1054
#  - mountain ↔ man: 0.1055
#  - boy ↔ ray: 0.1097
#  - bear ↔ man: 0.1119
#  - boy ↔ baby: 0.1125
#  - girl ↔ baby: 0.1131
#  - sea ↔ man: 0.1168

# %%
def study_from_file(file, title):
    with open(file, 'r') as f:
        cds = json.load(f)
    semantic = encode_descriptions(cds)
    
    study_semantics(semantic, title)

# %%
# Wordnet descriptions

study_from_file("wn_descriptions.json", "WordNet embeddings")
# Out:
# Model:  WordNet embeddings
# Interclass entropy: 9.852718786752218
# Histogram interclass entropy: 4.523299670947397
# Cluster 0: bear, elephant, hamster, kangaroo, lion, mouse, porcupine, possum, rabbit, raccoon, shrew, skunk, squirrel, tiger, wolf, beaver, camel, cattle, fox, leopard, chimpanzee, otter, black-footed_ferret, white_wolf, three-toed_sloth, house_finch, meerkat, dugong, African_hunting_dog, Arctic_fox
# Cluster 1: boy, bridge, cloud, forest, girl, house, mountain, road, lamp, man, plain, woman, baby, sea, telephone, scoreboard, prayer_rug, miniskirt, electric_guitar, dome, iPod, cliff
# Cluster 2: chair, couch, streetcar, motorcycle, tractor, bed, bicycle, pickup_truck, rocket, stage, unicycle, carousel
# Cluster 3: aquarium_fish, bottle, bowl, can, clock, cup, keyboard, lawn_mower, plate, table, television, wardrobe, cocktail_shaker, file, missile, lipstick, solar_dish, ashcan, hourglass, combination_lock, mixing_bowl, consomme, carton, poncho, wok, pencil_box, barrel, fire_screen, yawl, photocopier, cuirass, slot, clog, frying_pan, crate, dishrag, holster, vase, beer_bottle, trifle, hair_slide
# Cluster 4: caterpillar, lizard, spider, beetle, butterfly, crab, crocodile, rhinoceros_beetle, robin, hotdog, toucan, triceratops, king_crab, ladybug, harvestman, ear, spider_web, ant
# Cluster 5: apple, oak_tree, orange, orchid, palm_tree, pear, pine_tree, sunflower, tulip, willow_tree, maple_tree, poppy, rose, sweet_pepper, bolete
# Cluster 6: bee, cockroach, dinosaur, dolphin, lobster, mushroom, ray, seal, snake, trout, turtle, flatfish, shark, snail, whale, worm, goose, jellyfish, coral_reef, rock_beauty, nematode, green_mamba
# Cluster 7: organ, theater_curtain, upright, horizontal_bar, reel, parallel_bars, catamaran, chime, worm_fence, oboe, snorkel
# Cluster 8: bus, castle, skyscraper, tank, train, garbage_truck, tile_roof, tobacco_shop, street_sign, bookshop, aircraft_carrier, cannon, school_bus
# Cluster 9: Newfoundland, Saluki, malamute, miniature_poodle, golden_retriever, dalmatian, Gordon_setter, Walker_hound, boxer, Ibizan_hound, komondor, French_bulldog, Tibetan_mastiff
#  * Min distance:  0.0593
#  * Max distance:  0.7683
#  * Mean distance: 0.4578
# 🔍 Top k Most Similar Classes:
#  - man ↔ woman: 0.0593
#  - tiger ↔ leopard: 0.0753
#  - tulip ↔ poppy: 0.0788
#  - bicycle ↔ unicycle: 0.0814
#  - wok ↔ frying_pan: 0.0817
#  - horizontal_bar ↔ parallel_bars: 0.0887
#  - boy ↔ girl: 0.1003
#  - bottle ↔ barrel: 0.1470
#  - motorcycle ↔ unicycle: 0.1565
#  - tractor ↔ bicycle: 0.1583

# %%
study_from_file("gpt_descriptions.json", "GPT embeddings")
# Out:
# Model:  GPT embeddings
# Interclass entropy: 8.482092754571214
# Histogram interclass entropy: 4.948115330464122
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.0743
#  * Max distance:  0.6458
#  * Mean distance: 0.3957
# 🔍 Top k Most Similar Classes:
#  - hamster ↔ mouse: 0.0743
#  - hamster ↔ squirrel: 0.0743
#  - mouse ↔ squirrel: 0.0775
#  - lobster ↔ crab: 0.0915
#  - bear ↔ camel: 0.1046
#  - rabbit ↔ shrew: 0.1050
#  - boy ↔ man: 0.1064
#  - mouse ↔ rabbit: 0.1156
#  - hamster ↔ rabbit: 0.1162
#  - kangaroo ↔ possum: 0.1195

# %%
study_from_file("groq_img_descriptions.json", "groq_img_descriptions")
# Out:
# Model:  groq_img_descriptions
# Interclass entropy: 8.488234371164541
# Histogram interclass entropy: 4.862796313340406
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.1355
#  * Max distance:  0.6708
#  * Mean distance: 0.3936
# 🔍 Top k Most Similar Classes:
#  - lobster ↔ crab: 0.1355
#  - palm_tree ↔ pine_tree: 0.1449
#  - shark ↔ whale: 0.1474
#  - trout ↔ shark: 0.1540
#  - mouse ↔ shrew: 0.1579
#  - boy ↔ man: 0.1622
#  - bear ↔ beaver: 0.1711
#  - bee ↔ spider: 0.1720
#  - bowl ↔ cup: 0.1720
#  - mouse ↔ fox: 0.1723

# %%
study_from_file("gemini_img_descriptions.json", "gemini_img_descriptions")
# Out:
# Model:  gemini_img_descriptions
# Interclass entropy: 8.48266384782966
# Histogram interclass entropy: 4.701767839253125
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.1280
#  * Max distance:  0.7810
#  * Mean distance: 0.3842
# 🔍 Top k Most Similar Classes:
#  - dolphin ↔ whale: 0.1280
#  - tractor ↔ pickup_truck: 0.1434
#  - chair ↔ table: 0.1449
#  - motorcycle ↔ bicycle: 0.1492
#  - wolf ↔ fox: 0.1494
#  - lizard ↔ snake: 0.1533
#  - rabbit ↔ squirrel: 0.1540
#  - chair ↔ couch: 0.1570
#  - lion ↔ tiger: 0.1590
#  - spider ↔ beetle: 0.1622

# %%
study_from_file("gemini_text_descriptions.json", "gemini_text_descriptions")
# Out:
# Model:  gemini_text_descriptions
# Interclass entropy: 8.485353408236945
# Histogram interclass entropy: 4.888673318110951
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.1300
#  * Max distance:  0.6940
#  * Mean distance: 0.3947
# 🔍 Top k Most Similar Classes:
#  - lion ↔ tiger: 0.1300
#  - mouse ↔ squirrel: 0.1366
#  - motorcycle ↔ bicycle: 0.1368
#  - lobster ↔ crab: 0.1378
#  - lion ↔ leopard: 0.1482
#  - bowl ↔ cup: 0.1531
#  - palm_tree ↔ pine_tree: 0.1537
#  - tiger ↔ leopard: 0.1538
#  - wolf ↔ fox: 0.1566
#  - hamster ↔ mouse: 0.1569

# %%
study_from_file("groq_prompt0.json", "groq_prompt0")
# Out:
# Model:  groq_prompt0
# Interclass entropy: 8.4873647393041
# Histogram interclass entropy: 4.875693571195437
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.1180
#  * Max distance:  0.6149
#  * Mean distance: 0.3595
# 🔍 Top k Most Similar Classes:
#  - couch ↔ bed: 0.1180
#  - boy ↔ girl: 0.1190
#  - chair ↔ table: 0.1235
#  - chair ↔ couch: 0.1310
#  - girl ↔ woman: 0.1315
#  - mountain ↔ plain: 0.1375
#  - palm_tree ↔ pine_tree: 0.1420
#  - bowl ↔ cup: 0.1478
#  - dolphin ↔ whale: 0.1480
#  - motorcycle ↔ bicycle: 0.1491

# %%
study_from_file("groq_prompt1.json", "groq_prompt1")
# Out:
# Model:  groq_prompt1
# Interclass entropy: 8.486669277052979
# Histogram interclass entropy: 4.975320557099978
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.1073
#  * Max distance:  0.5728
#  * Mean distance: 0.3586
# 🔍 Top k Most Similar Classes:
#  - girl ↔ woman: 0.1073
#  - boy ↔ man: 0.1198
#  - bear ↔ rabbit: 0.1272
#  - boy ↔ baby: 0.1300
#  - man ↔ woman: 0.1373
#  - girl ↔ baby: 0.1381
#  - lizard ↔ snake: 0.1385
#  - boy ↔ girl: 0.1397
#  - mouse ↔ squirrel: 0.1402
#  - boy ↔ woman: 0.1444

# %%
study_from_file("groq_prompt2.json", "groq_prompt2")
# Out:
# Model:  groq_prompt2
# Interclass entropy: 8.488848999645661
# Histogram interclass entropy: 4.749045875853667
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.0924
#  * Max distance:  0.5834
#  * Mean distance: 0.3423
# 🔍 Top k Most Similar Classes:
#  - girl ↔ woman: 0.0924
#  - man ↔ woman: 0.1135
#  - couch ↔ bed: 0.1180
#  - boy ↔ man: 0.1189
#  - motorcycle ↔ bicycle: 0.1201
#  - bowl ↔ cup: 0.1285
#  - shark ↔ whale: 0.1296
#  - chair ↔ couch: 0.1326
#  - dolphin ↔ whale: 0.1346
#  - girl ↔ man: 0.1347

# %%
study_from_file("groq_prompt3.json", "groq_prompt3")
# Out:
# Model:  groq_prompt3
# Interclass entropy: 8.487555702898089
# Histogram interclass entropy: 4.8819239972909525
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.1084
#  * Max distance:  0.6154
#  * Mean distance: 0.3719
# 🔍 Top k Most Similar Classes:
#  - girl ↔ woman: 0.1084
#  - bear ↔ rabbit: 0.1393
#  - man ↔ woman: 0.1413
#  - boy ↔ man: 0.1416
#  - bear ↔ wolf: 0.1456
#  - bear ↔ cattle: 0.1488
#  - oak_tree ↔ maple_tree: 0.1496
#  - bottle ↔ cup: 0.1510
#  - boy ↔ girl: 0.1517
#  - wolf ↔ fox: 0.1524

# %%
study_from_file("gemini_prompt3.json", "gemini_prompt3")
# Out:
# Model:  gemini_prompt3
# Interclass entropy: 8.485736402700434
# Histogram interclass entropy: 4.85112881173244
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.1128
#  * Max distance:  0.6663
#  * Mean distance: 0.3818
# 🔍 Top k Most Similar Classes:
#  - bowl ↔ cup: 0.1128
#  - raccoon ↔ wolf: 0.1181
#  - chair ↔ couch: 0.1218
#  - bear ↔ wolf: 0.1335
#  - tulip ↔ poppy: 0.1420
#  - bottle ↔ cup: 0.1420
#  - motorcycle ↔ bicycle: 0.1434
#  - lion ↔ tiger: 0.1435
#  - lizard ↔ snake: 0.1447
#  - couch ↔ bed: 0.1447

# %%
study_from_file("gemini_prompt2.json", "gemini_prompt2")
# Out:
# Model:  gemini_prompt2
# Interclass entropy: 8.479821060141697
# Histogram interclass entropy: 4.651788187543152
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.0747
#  * Max distance:  0.7201
#  * Mean distance: 0.3654
# 🔍 Top k Most Similar Classes:
#  - mouse ↔ shrew: 0.0747
#  - couch ↔ bed: 0.1213
#  - girl ↔ woman: 0.1270
#  - man ↔ woman: 0.1271
#  - motorcycle ↔ bicycle: 0.1321
#  - bowl ↔ cup: 0.1336
#  - boy ↔ man: 0.1342
#  - chair ↔ couch: 0.1369
#  - dolphin ↔ whale: 0.1399
#  - wolf ↔ fox: 0.1426

# %%
study_from_file("meta-llama_llama-4-scout:free_descriptions.json", "meta-llama_scout")
# Out:
# Model:  meta-llama_scout
# Interclass entropy: 8.485139592185913
# Histogram interclass entropy: 4.875756024160694
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.0977
#  * Max distance:  0.5955
#  * Mean distance: 0.3439
# 🔍 Top k Most Similar Classes:
#  - bowl ↔ cup: 0.0977
#  - man ↔ woman: 0.1169
#  - apple ↔ pear: 0.1238
#  - motorcycle ↔ bicycle: 0.1294
#  - couch ↔ bed: 0.1309
#  - chair ↔ couch: 0.1329
#  - mouse ↔ squirrel: 0.1355
#  - bus ↔ train: 0.1362
#  - girl ↔ woman: 0.1398
#  - chair ↔ table: 0.1407

# %%
study_from_file("meta-llama_llama-4-maverick:free_descriptions.json", "meta-llama-maverick")
# Out:
# Model:  meta-llama-maverick
# Interclass entropy: 8.486089584528845
# Histogram interclass entropy: 4.872883823270782
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.0791
#  * Max distance:  0.5525
#  * Mean distance: 0.3349
# 🔍 Top k Most Similar Classes:
#  - girl ↔ woman: 0.0791
#  - boy ↔ man: 0.1015
#  - couch ↔ bed: 0.1040
#  - boy ↔ girl: 0.1122
#  - man ↔ woman: 0.1278
#  - apple ↔ pear: 0.1282
#  - oak_tree ↔ maple_tree: 0.1313
#  - shark ↔ whale: 0.1314
#  - mouse ↔ squirrel: 0.1315
#  - girl ↔ baby: 0.1387

# %%
study_from_file("mistralai_mistral-small-3.1-24b-instruct:free_descriptions.json", "mistralai")
# Out:
# Model:  mistralai
# Interclass entropy: 8.486387601869133
# Histogram interclass entropy: 4.762257882199289
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.1051
#  * Max distance:  0.6659
#  * Mean distance: 0.3709
# 🔍 Top k Most Similar Classes:
#  - motorcycle ↔ bicycle: 0.1051
#  - boy ↔ man: 0.1308
#  - man ↔ woman: 0.1373
#  - boy ↔ girl: 0.1398
#  - mouse ↔ squirrel: 0.1423
#  - bowl ↔ cup: 0.1426
#  - girl ↔ woman: 0.1469
#  - lizard ↔ snake: 0.1478
#  - wolf ↔ fox: 0.1577
#  - oak_tree ↔ maple_tree: 0.1610

# %%
study_from_file("google_gemma-3-27b-it:free_descriptions.json", "google_gemma")
# Out:
# Model:  google_gemma
# Interclass entropy: 8.488413928129116
# Histogram interclass entropy: 4.867934292161102
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.0974
#  * Max distance:  0.5956
#  * Mean distance: 0.3704
# 🔍 Top k Most Similar Classes:
#  - girl ↔ woman: 0.0974
#  - motorcycle ↔ bicycle: 0.1294
#  - boy ↔ girl: 0.1390
#  - mountain ↔ plain: 0.1508
#  - bee ↔ spider: 0.1520
#  - wolf ↔ fox: 0.1544
#  - rabbit ↔ squirrel: 0.1555
#  - couch ↔ bed: 0.1561
#  - mouse ↔ squirrel: 0.1621
#  - camel ↔ cattle: 0.1641

# %%
study_from_file("qwen_qwen2.5-vl-72b-instruct:free_descriptions.json", "qwen")
# Out:
# Model:  qwen
# Interclass entropy: 8.487430701852688
# Histogram interclass entropy: 4.780754962796209
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.0829
#  * Max distance:  0.6109
#  * Mean distance: 0.3594
# 🔍 Top k Most Similar Classes:
#  - girl ↔ woman: 0.0829
#  - boy ↔ man: 0.1094
#  - couch ↔ bed: 0.1118
#  - chair ↔ couch: 0.1191
#  - bowl ↔ plate: 0.1334
#  - motorcycle ↔ bicycle: 0.1393
#  - chair ↔ table: 0.1428
#  - man ↔ woman: 0.1429
#  - mouse ↔ squirrel: 0.1454
#  - dolphin ↔ whale: 0.1464

# %%
study_from_file("deepseek_deepseek-r1:free_descriptions.json", "LLM improved")
# Out:
# Model:  LLM improved
# Interclass entropy: 8.48541046849279
# Histogram interclass entropy: 4.834889046861192
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.1135
#  * Max distance:  0.6737
#  * Mean distance: 0.3802
# 🔍 Top k Most Similar Classes:
#  - girl ↔ woman: 0.1135
#  - man ↔ woman: 0.1282
#  - boy ↔ girl: 0.1388
#  - bowl ↔ cup: 0.1408
#  - tractor ↔ pickup_truck: 0.1430
#  - chair ↔ couch: 0.1464
#  - wolf ↔ fox: 0.1491
#  - mouse ↔ squirrel: 0.1512
#  - motorcycle ↔ bicycle: 0.1538
#  - dolphin ↔ whale: 0.1578

# %%
import torch, json
DEVICE = "cpu"
with open("imgnet_mapping.json", 'r') as f:
    imap = json.load(f)
default_path = "/Users/jdieguez/Documents/master/TFM/code/TFM-SemFew/Model/semantic/imagenet_semantic_clip_gpt.pth"
semantic = torch.load(default_path, map_location=DEVICE)['semantic_feature']
semantic = {k: v.float() for k, v in semantic.items()}
semantic = {imap[cls]: semantic[cls] for cls in semantic.keys()}

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
methods = ['Names', 'WordNet', 'LLM']
mix_acc = [75.06, 73.88, 83.51]
mix_acc5 = [86.60, 86.43, 87.08]

# Bar positions for groups
x = np.arange(2)  # Keep groups close together (0 and 1)

# Smaller width to allow space between bars
width = 0.18

# Increase offsets so bars don’t touch
offsets = [-width * 1.5, 0, width * 1.5]

fig, ax = plt.subplots(figsize=(8, 6))

# Plot bars for each method with new offsets and width
bars = []
bars.append(ax.bar(x[0] + offsets[0], mix_acc[0], width))
bars.append(ax.bar(x[0] + offsets[1], mix_acc[1], width))
bars.append(ax.bar(x[0] + offsets[2], mix_acc[2], width))

bars.append(ax.bar(x[1] + offsets[0], mix_acc5[0], width))
bars.append(ax.bar(x[1] + offsets[1], mix_acc5[1], width))
bars.append(ax.bar(x[1] + offsets[2], mix_acc5[2], width))

# Legend bars
method_bars = [
    ax.bar(0, 0, color='teal', label='Names'),
    ax.bar(0, 0, color='salmon', label='WordNet'),
    ax.bar(0, 0, color='mediumpurple', label='LLM'),
]

colors = ['teal', 'salmon', 'mediumpurple']
for i, color in enumerate(colors):
    bars[i].patches[0].set_color(color)
    bars[i+3].patches[0].set_color(color)

# Add text labels
for group_idx, (group_vals, xpos) in enumerate(zip([mix_acc, mix_acc5], x)):
    for i in range(len(methods)):
        val = group_vals[i]
        ax.annotate(f'{val:.2f}',
                    xy=(xpos + offsets[i], val),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=20)

# X-axis labels
ax.set_xticks(x)
ax.set_xticklabels(['1-shot', '5-shot'], fontsize=20)
ax.set_ylabel('Acc', fontsize=20)
ax.set_title('Comparison of Accuracy', fontsize=20)

# Legend
ax.legend(handles=method_bars, fontsize=16)

ax.set_ylim(0, 110)
plt.tight_layout()
plt.show()

fig.savefig('/Users/jdieguez/Downloads/mix_acc.png')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
methods = ['Names', 'WordNet', 'LLM']
gap = [2.51, 1.33, 10.96]
gap5 = [0.78, 0.36, 1.01]

# Bar positions for groups
x = np.arange(2)  # Keep groups close together (0 and 1)

# Smaller width to allow space between bars
width = 0.18

# Increase offsets so bars don’t touch
offsets = [-width * 1.5, 0, width * 1.5]

fig, ax = plt.subplots(figsize=(8, 6))

# Plot bars for each method with new offsets and width
bars = []
bars.append(ax.bar(x[0] + offsets[0], gap[0], width))
bars.append(ax.bar(x[0] + offsets[1], gap[1], width))
bars.append(ax.bar(x[0] + offsets[2], gap[2], width))

bars.append(ax.bar(x[1] + offsets[0], gap5[0], width))
bars.append(ax.bar(x[1] + offsets[1], gap5[1], width))
bars.append(ax.bar(x[1] + offsets[2], gap5[2], width))

# Legend bars
method_bars = [
    ax.bar(0, 0, color='teal', label='Names'),
    ax.bar(0, 0, color='salmon', label='WordNet'),
    ax.bar(0, 0, color='mediumpurple', label='LLM'),
]

colors = ['teal', 'salmon', 'mediumpurple']
for i, color in enumerate(colors):
    bars[i].patches[0].set_color(color)
    bars[i+3].patches[0].set_color(color)

# Add text labels
for group_idx, (group_vals, xpos) in enumerate(zip([gap, gap5], x)):
    for i in range(len(methods)):
        val = group_vals[i]
        ax.annotate(f'{val:.2f}',
                    xy=(xpos + offsets[i], val),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=20)

# X-axis labels
ax.set_xticks(x)
ax.set_xticklabels(['1-shot', '5-shot'], fontsize=20)
ax.set_ylabel('Gap', fontsize=20)
ax.set_title('Comparison of Improvement', fontsize=20)

# Legend
ax.legend(handles=method_bars, fontsize=16)

ax.set_ylim(0, 13)
plt.tight_layout()
plt.show()

fig.savefig('/Users/jdieguez/Downloads/gap.png')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
methods = ['Names', 'WordNet', 'LLM']
mix_acc = [75.06, 73.88, 83.51]
gap = [2.51, 1.33, 10.96]

# Bar parameters
width = 0.2
offsets = [-width * 1.5, 0, width * 1.5]

x = 0  # single group for each axis, so x=0 for both but different axes

fig, ax1 = plt.subplots(figsize=(8, 5))
ax2 = ax1.twinx()  # second y-axis

colors = ['teal', 'salmon', 'mediumpurple']

# Plot Mix Acc bars on ax1 (left y-axis)
bars_mix = []
for i in range(len(methods)):
    bars_mix.append(ax1.bar(x + offsets[i], mix_acc[i], width, color=colors[i]))

# Plot Gap bars on ax2 (right y-axis)
bars_gap = []
for i in range(len(methods)):
    bars_gap.append(ax2.bar(x + offsets[i], gap[i], width, color=colors[i], alpha=0.6))

# Set x-axis ticks and labels — just one group
ax1.set_xticks([x])
ax1.set_xticklabels(['Mix Acc and Gap'])

# Set labels and titles
ax1.set_ylabel('Mix Acc (%)', color='black')
ax2.set_ylabel('Gap (%)', color='black')
ax1.set_title('Comparison of Methods with Different Scales')

# Set limits for clarity
ax1.set_ylim(60, 90)
ax2.set_ylim(0, 15)

# Annotate values above bars on ax1
for i in range(len(methods)):
    ax1.annotate(f'{mix_acc[i]:.2f}', 
                 xy=(x + offsets[i], mix_acc[i]), 
                 xytext=(0, 3), textcoords="offset points", 
                 ha='center', va='bottom', fontsize=9)

# Annotate values above bars on ax2
for i in range(len(methods)):
    ax2.annotate(f'{gap[i]:.2f}', 
                 xy=(x + offsets[i], gap[i]), 
                 xytext=(0, 3), textcoords="offset points", 
                 ha='center', va='bottom', fontsize=9)

# Create custom legend
from matplotlib.patches import Patch
legend_patches = [Patch(color=colors[i], label=methods[i]) for i in range(len(methods))]
ax1.legend(handles=legend_patches)

plt.tight_layout()
plt.show()
