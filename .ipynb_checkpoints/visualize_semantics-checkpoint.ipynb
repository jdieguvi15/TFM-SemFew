# %%
import torch

if torch.cuda.is_available():
    DEVICE = torch.device("cuda")
elif torch.backends.mps.is_available():
    DEVICE = torch.device("mps")
else:
    DEVICE = torch.device("cpu")

# %%
import open_clip

def encode_descriptions(class_descriptions):
    # Load CLIP
    model, _, preprocess = open_clip.create_model_and_transforms('ViT-B-32', pretrained='laion2b_s34b_b79k')
    tokenizer = open_clip.get_tokenizer('ViT-B-32')
    model = model.to(DEVICE).eval()

    # Encode the descriptions
    class_names = list(class_descriptions.keys())
    text_descriptions = list(class_descriptions.values())
    with torch.no_grad():
        text_tokens = tokenizer(text_descriptions).to(DEVICE)
        text_features = model.encode_text(text_tokens)
        text_features /= text_features.norm(dim=-1, keepdim=True)

    semantics = {class_names[i]: text_features[i] for i in range(len(class_names))}
    return semantics

# %%
import json

with open("wn_descriptions.json", 'r') as f:
    cds = json.load(f)

# %%
cds
# Out:
# {'apple': 'fruit with red or yellow or green skin and sweet to tart crisp whitish flesh',
#  'aquarium_fish': 'a tank or pool or bowl filled with water for keeping live fish and underwater animals',
#  'bear': 'massive plantigrade carnivorous or omnivorous mammals with long shaggy coats and strong claws',
#  'bee': 'any of numerous hairy-bodied insects including social and solitary species',
#  'bottle': 'a glass or plastic vessel used for storing drinks or other liquids; typically cylindrical without handles and with a narrow neck that can be plugged or capped',
#  'bowl': 'a round vessel that is open at the top; used chiefly for holding food or liquids',
#  'boy': 'a youthful male person',
#  'bridge': 'a structure that allows people or vehicles to cross an obstacle such as a river or canal or railway etc.',
#  'bus': 'a vehicle carrying many passengers; used for public transport',
#  'can': 'airtight sealed metal container for food or drink or paint etc.',
#  'castle': 'a large building formerly occupied by a ruler and fortified against attack',
#  'caterpillar': 'a wormlike and often brightly colored and hairy or spiny larva of a butterfly or moth',
#  'chair': 'a seat for one person, with a support for the back',
#  'clock': 'a timepiece that shows the time of day',
#  'cloud': 'a visible mass of water or ice particles suspended at a considerable altitude',
#  'cockroach': 'any of numerous chiefly nocturnal insects; some are domestic pests',
#  'couch': 'an upholstered seat for more than one person',
#  'cup': 'a small open container usually used for drinking; usually has a handle',
#  'dinosaur': 'any of numerous extinct terrestrial reptiles of the Mesozoic era',
#  'dolphin': 'any of various small toothed whales with a beaklike snout; larger than porpoises',
#  'elephant': 'five-toed pachyderm',
#  'forest': 'land that is covered with trees and shrubs',
#  'girl': 'a youthful female person',
#  'hamster': 'short-tailed Old World burrowing rodent with large cheek pouches',
#  'house': 'a dwelling that serves as living quarters for one or more families',
#  'kangaroo': 'any of several herbivorous leaping marsupials of Australia and New Guinea having large powerful hind legs and a long thick tail',
#  'keyboard': 'device consisting of a set of keys on a piano or organ or typewriter or typesetting machine or computer or the like',
#  'lawn_mower': 'garden tool for mowing grass on lawns',
#  'lion': 'large gregarious predatory feline of Africa and India having a tawny coat with a shaggy mane in the male',
#  'lizard': 'relatively long-bodied reptile with usually two pairs of legs and a tapering tail',
#  'lobster': 'any of several edible marine crustaceans of the families Homaridae and Nephropsidae and Palinuridae',
#  'mountain': 'a land mass that projects well above its surroundings; higher than a hill',
#  'mouse': 'any of numerous small rodents typically resembling diminutive rats having pointed snouts and small ears on elongated bodies with slender usually hairless tails',
#  'mushroom': 'fleshy body of any of numerous edible fungi',
#  'oak_tree': 'a deciduous tree of the genus Quercus; has acorns and lobed leaves',
#  'orange': 'round yellow to orange fruit of any of several citrus trees',
#  'orchid': 'any of numerous plants of the orchid family usually having flowers of unusual shapes and beautiful colors',
#  'palm_tree': 'any plant of the family Palmae having an unbranched trunk crowned by large pinnate or palmate leaves',
#  'pear': 'sweet juicy gritty-textured fruit available in many varieties',
#  'pine_tree': 'a coniferous tree',
#  'plate': 'dish on which food is served or from which food is eaten',
#  'porcupine': 'relatively large rodents with sharp erectile bristles mingled with the fur',
#  'possum': 'small furry Australian arboreal marsupials having long usually prehensile tails',
#  'rabbit': 'any of various burrowing animals of the family Leporidae having long ears and short tails; some domesticated and raised for pets or food',
#  'raccoon': 'an omnivorous nocturnal mammal native to North America and Central America',
#  'ray': 'cartilaginous fishes having horizontally flattened bodies and enlarged winglike pectoral fins with gills on the underside; most swim by moving the pectoral fins',
#  'road': 'an open way (generally public) for travel or transportation',
#  'seal': 'any of numerous marine mammals that come on shore to breed; chiefly of cold regions',
#  'shrew': 'small mouselike mammal with a long snout; related to moles',
#  'skunk': 'American musteline mammal typically ejecting an intensely malodorous fluid when startled; in some classifications put in a separate subfamily Mephitinae',
#  'skyscraper': 'a very tall building with many stories',
#  'snake': 'limbless scaly elongate reptile; some are venomous',
#  'spider': 'predatory arachnid with eight legs, two poison fangs, two feelers, and usually two silk-spinning organs at the back end of the body; they spin silk to make cocoons for eggs or traps for prey',
#  'squirrel': 'a kind of arboreal rodent having a long bushy tail',
#  'streetcar': 'a wheeled vehicle that runs on rails and is propelled by electricity',
#  'sunflower': 'any plant of the genus Helianthus having large flower heads with dark disk florets and showy yellow rays',
#  'tank': 'an enclosed armored military vehicle; has a cannon and moves on caterpillar treads',
#  'tiger': 'large feline of forests in most of Asia having a tawny coat with black stripes; endangered',
#  'train': 'public transport provided by a line of railway cars coupled together and drawn by a locomotive',
#  'trout': 'any of various game and food fishes of cool fresh waters mostly smaller than typical salmons',
#  'tulip': 'any of numerous perennial bulbous herbs having linear or broadly lanceolate leaves and usually a single showy flower',
#  'turtle': 'any of various aquatic and land reptiles having a bony shell and flipper-like limbs for swimming',
#  'willow_tree': 'any of numerous deciduous trees and shrubs of the genus Salix',
#  'wolf': 'any of various predatory carnivorous canine mammals of North America and Eurasia that usually hunt in packs',
#  'beaver': 'large semiaquatic rodent with webbed hind feet and a broad flat tail; construct complex dams and underwater lodges',
#  'beetle': 'insect having biting mouthparts and front wings modified to form horny covers overlying the membranous rear wings',
#  'butterfly': 'diurnal insect typically having a slender body with knobbed antennae and broad colorful wings',
#  'camel': 'cud-chewing mammal used as a draft or saddle animal in desert regions',
#  'cattle': 'domesticated bovine animals as a group regardless of sex or age',
#  'crab': 'decapod having eyes on short stalks and a broad flattened carapace with a small abdomen folded under the thorax and pincers',
#  'crocodile': 'large voracious aquatic reptile having a long snout with massive jaws and sharp teeth and a body covered with bony plates; of sluggish tropical waters',
#  'fox': 'alert carnivorous mammal with pointed muzzle and ears and a bushy tail; most are predators that do not hunt in packs',
#  'lamp': 'an artificial source of visible illumination',
#  'leopard': 'large feline of African and Asian forests usually having a tawny coat with black spots',
#  'man': 'an adult person who is male (as opposed to a woman)',
#  'maple_tree': 'any of numerous trees or shrubs of the genus Acer bearing winged seeds in pairs; north temperate zone',
#  'motorcycle': 'a motor vehicle with two wheels and a strong frame',
#  'plain': 'extensive tract of level open land',
#  'poppy': 'annual or biennial or perennial herbs having showy flowers',
#  'rose': 'any of many shrubs of the genus Rosa that bear roses',
#  'table': 'a piece of furniture having a smooth flat top that is usually supported by one or more vertical legs',
#  'tractor': 'a wheeled vehicle with large wheels; used in farming and other applications',
#  'woman': 'an adult female person (as opposed to a man)',
#  'baby': 'a very young child (birth to 1 year) who has not yet begun to walk or talk',
#  'bed': 'a piece of furniture that provides a place to sleep',
#  'bicycle': 'a wheeled vehicle that has two wheels and is moved by foot pedals',
#  'chimpanzee': 'intelligent somewhat arboreal ape of equatorial African forests',
#  'flatfish': 'sweet lean whitish flesh of any of numerous thin-bodied fish; usually served as thin fillets',
#  'otter': 'freshwater carnivorous mammal having webbed and clawed feet and dark brown fur',
#  'pickup_truck': 'a light truck with an open body and low sides and a tailboard',
#  'rocket': 'any vehicle self-propelled by a rocket engine',
#  'sea': 'a division of an ocean or a large body of salt water partially enclosed by land',
#  'shark': 'any of numerous elongate mostly marine carnivorous fishes with heterocercal caudal fins and tough skin covered with small toothlike scales',
#  'snail': 'freshwater or marine or terrestrial gastropod mollusk usually having an external enclosing spiral shell',
#  'sweet_pepper': 'plant bearing large mild thick-walled usually bell-shaped fruits; the principal salad peppers',
#  'telephone': 'electronic equipment that converts sound into electrical signals that can be transmitted over distances and then converts received signals back into sounds',
#  'television': 'an electronic device that receives television signals and displays them on a screen',
#  'wardrobe': 'a tall piece of furniture that provides storage space for clothes; has a door and rails or hooks for hanging clothes',
#  'whale': 'any of the larger cetacean mammals having a streamlined body and breathing through a blowhole on the head',
#  'worm': 'any of numerous relatively small elongated soft-bodied animals especially of the phyla Annelida and Chaetognatha and Nematoda and Nemertea and Platyhelminthes; also many insect larvae'}

# %%
default_path = "/Users/jdieguez/Documents/master/TFM/code/TFM-SemFew/Model/semantic/cifar100_semantic_clip_gpt.pth"
semantic = torch.load(default_path, map_location=DEVICE)['semantic_feature']
semantic = {k: v.float() for k, v in semantic.items()}

# %%
semantic['train'].shape
# Out:
# torch.Size([512])

# %%
import torch
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

def visualize(encodings, title="2D Visualization"):
    # Convert to a matrix
    class_names = list(encodings.keys())
    vectors = torch.stack([encodings[cls] for cls in class_names])
    
    # Apply t-SNE
    tsne = TSNE(n_components=2, random_state=42, perplexity=30, init='pca')
    vectors_2d = tsne.fit_transform(vectors.cpu().numpy())
    
    # Plot
    plt.figure(figsize=(12, 10))
    for i, label in enumerate(class_names):
        x, y = vectors_2d[i]
        plt.scatter(x, y)
        plt.text(x + 0.3, y + 0.3, label, fontsize=8)
    
    plt.title(title)
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
visualize(semantic)

# %%
import torch
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.spatial.distance import pdist, squareform
from scipy.stats import entropy

# Interclass entropy with distances
def interclass_entropy(class_encodings, metric='cosine'):
    dists = pdist(class_encodings.cpu().numpy(), metric=metric)
    prob = dists / dists.sum()
    return entropy(prob)

# Interclass entropy based on histogram (focuses more on the shape)
def interclass_entropy_histogram(class_encodings, metric='cosine', bins=50):
    dists = pdist(class_encodings.cpu().numpy(), metric=metric)
    hist, _ = np.histogram(dists, bins=bins, density=True)
    hist += 1e-9  # prevent log(0)
    return entropy(hist, base=2)

# %%
def analyze_class_distances(embeddings_dict, k=10, metric='cosine', show=True):
    class_names = list(embeddings_dict.keys())
    encodings = torch.stack([embeddings_dict[cls] for cls in class_names])

    distances = pdist(encodings.cpu().numpy(), metric=metric)
    distance_matrix = squareform(distances)

    # Global statistics
    finite_distances = distances[np.isfinite(distances)]  # safety check
    min_dist = np.min(finite_distances)
    max_dist = np.max(finite_distances)
    mean_dist = np.mean(finite_distances)
    print(f" * Min distance:  {min_dist:.4f}")
    print(f" * Max distance:  {max_dist:.4f}")
    print(f" * Mean distance: {mean_dist:.4f}")

    df = pd.DataFrame(distance_matrix, index=class_names, columns=class_names)

    # Calculate Top k most similar embeddings
    np.fill_diagonal(distance_matrix, np.nan)  # ignore self-distances
    triu_indices = np.triu_indices_from(distance_matrix, k=1)
    sorted_indices = np.argsort(distance_matrix[triu_indices])
    
    top_k_pairs = [(class_names[i], class_names[j], distance_matrix[i, j])
                    for i, j in zip(triu_indices[0][sorted_indices[:k]],
                                    triu_indices[1][sorted_indices[:k]])]

    print("🔍 Top k Most Similar Classes:")
    for a, b, d in top_k_pairs:
        print(f" - {a} ↔ {b}: {d:.4f}")

    if show:
        # Plot heatmap
        plt.figure(figsize=(20, 16))
        sns.heatmap(df, cmap="viridis", xticklabels=True, yticklabels=True)
        plt.title(f'Pairwise {metric.capitalize()} Distances Between Class Encodings')
        plt.xlabel('Class')
        plt.ylabel('Class')
        plt.tight_layout()
        plt.show()

    return df

# %%
df = analyze_class_distances(semantic)
# Out:
# 🔍 Top 20 Most Similar Classes:
#  - girl ↔ woman: 0.0202
#  - dolphin ↔ whale: 0.0368
#  - snake ↔ lizard: 0.0373
#  - man ↔ woman: 0.0391
#  - wolf ↔ fox: 0.0404
#  - squirrel ↔ hamster: 0.0408
#  - bear ↔ hamster: 0.0413
#  - bear ↔ rabbit: 0.0422
#  - bus ↔ streetcar: 0.0425
#  - bear ↔ cattle: 0.0429
#  - caterpillar ↔ worm: 0.0448
#  - hamster ↔ rabbit: 0.0451
#  - bottle ↔ cup: 0.0454
#  - cockroach ↔ beetle: 0.0455
#  - mountain ↔ plain: 0.0475
#  - shrew ↔ hamster: 0.0478
#  - hamster ↔ skunk: 0.0479
#  - otter ↔ beaver: 0.0479
#  - possum ↔ squirrel: 0.0485
#  - pear ↔ apple: 0.0487

# %%
import torch
import numpy as np
from scipy.spatial.distance import pdist
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
import matplotlib.pyplot as plt

def cluster_classes(embeddings_dict, metric='cosine', num_clusters=None, distance_threshold=None):
    class_names = list(embeddings_dict.keys())
    encodings = torch.stack([embeddings_dict[cls] for cls in class_names]).cpu().numpy()

    # Pairwise distances
    pairwise_dist = pdist(encodings, metric=metric)

    # Linkage matrix
    Z = linkage(pairwise_dist, method='average')  # Other methods: 'ward', 'single', 'complete'

    # Cluster them with different methods
    if num_clusters:
        clusters = fcluster(Z, t=num_clusters, criterion='maxclust')
    elif distance_threshold:
        clusters = fcluster(Z, t=distance_threshold, criterion='distance')
    else:
        clusters = None  # No cutting, only dendrogram

    # Plot dendrogram
    plt.figure(figsize=(12, 6))
    dendrogram(Z, labels=class_names, leaf_rotation=90)
    plt.title(f'Hierarchical Clustering of Classes ({metric} distance)')
    plt.xlabel('Class')
    plt.ylabel('Distance')
    plt.tight_layout()
    plt.show()

    # Print clusters
    if clusters is not None:
        from collections import defaultdict
        cluster_groups = defaultdict(list)
        for cls, cluster_id in zip(class_names, clusters):
            cluster_groups[cluster_id].append(cls)

        print("🔍 Clustered Classes:")
        for cluster_id, members in sorted(cluster_groups.items()):
            print(f" - Cluster {cluster_id}: {members}")

        return cluster_groups

    return Z  # return linkage matrix if clusters not formed yet

# %%
clusters = cluster_classes(semantic, distance_threshold=0.14)
# Out:
# 🔍 Clustered Classes:
#  - Cluster 1: ['sunflower', 'tulip', 'orchid', 'poppy', 'rose']
#  - Cluster 2: ['castle', 'bridge']
#  - Cluster 3: ['forest', 'pine_tree', 'oak_tree', 'willow_tree', 'palm_tree', 'maple_tree']
#  - Cluster 4: ['orange', 'pear', 'apple', 'mushroom', 'sweet_pepper']
#  - Cluster 5: ['skyscraper', 'turtle', 'spider', 'girl', 'seal', 'elephant', 'possum', 'squirrel', 'plate', 'wolf', 'road', 'mouse', 'boy', 'shrew', 'tiger', 'caterpillar', 'lion', 'dolphin', 'cockroach', 'bear', 'porcupine', 'bee', 'hamster', 'lobster', 'bowl', 'can', 'bottle', 'trout', 'snake', 'skunk', 'lizard', 'cup', 'kangaroo', 'dinosaur', 'rabbit', 'ray', 'mountain', 'house', 'baby', 'chimpanzee', 'fox', 'leopard', 'man', 'plain', 'rocket', 'snail', 'wardrobe', 'whale', 'woman', 'worm', 'otter', 'crocodile', 'shark', 'butterfly', 'beaver', 'beetle', 'flatfish', 'camel', 'crab', 'sea', 'cattle']
#  - Cluster 6: ['keyboard', 'telephone', 'television']
#  - Cluster 7: ['train', 'bus', 'chair', 'tank', 'couch', 'streetcar', 'lawn_mower', 'bed', 'bicycle', 'pickup_truck', 'table', 'motorcycle', 'tractor']
#  - Cluster 8: ['lamp']
#  - Cluster 9: ['raccoon']
#  - Cluster 10: ['cloud']
#  - Cluster 11: ['clock']
#  - Cluster 12: ['aquarium_fish']

# %%
import torch
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import pairwise_distances_argmin_min

def cluster_classes_kmeans(embeddings_dict, n_clusters=10, metric='cosine'):
    class_names = list(embeddings_dict.keys())
    class_encodings = torch.stack([embeddings_dict[cls] for cls in class_names])
    
    # Normalize encodings for cosine similarity
    norm_encodings = torch.nn.functional.normalize(class_encodings, dim=1)
    
    # KMeans with uses Euclidean distance but normalized
    kmeans = KMeans(n_clusters=n_clusters, random_state=42, n_init="auto")
    labels = kmeans.fit_predict(norm_encodings.cpu().numpy())

    # Group class names by cluster label
    clustered_classes = {}
    for idx, cluster_id in enumerate(labels):
        clustered_classes.setdefault(cluster_id, []).append(class_names[idx])

    # Cluster summary
    for cluster_id, class_list in clustered_classes.items():
        print(f"Cluster {cluster_id} ({len(class_list)} classes): {class_list}")

    return clustered_classes

# %%
clusters = cluster_classes_kmeans(semantic)
# Out:
# Cluster 2 (7 classes): ['train', 'bus', 'chair', 'streetcar', 'bicycle', 'pickup_truck', 'tractor']
# Cluster 1 (15 classes): ['skyscraper', 'castle', 'keyboard', 'tank', 'road', 'couch', 'lawn_mower', 'bridge', 'mountain', 'house', 'bed', 'plain', 'rocket', 'wardrobe', 'motorcycle']
# Cluster 6 (11 classes): ['turtle', 'seal', 'dolphin', 'trout', 'whale', 'otter', 'crocodile', 'shark', 'beaver', 'sea', 'aquarium_fish']
# Cluster 0 (29 classes): ['raccoon', 'girl', 'elephant', 'mushroom', 'possum', 'squirrel', 'wolf', 'mouse', 'boy', 'shrew', 'tiger', 'lion', 'bear', 'porcupine', 'hamster', 'snake', 'skunk', 'lizard', 'kangaroo', 'dinosaur', 'rabbit', 'baby', 'chimpanzee', 'fox', 'leopard', 'man', 'woman', 'camel', 'cattle']
# Cluster 5 (8 classes): ['spider', 'caterpillar', 'cockroach', 'bee', 'snail', 'worm', 'butterfly', 'beetle']
# Cluster 7 (7 classes): ['orange', 'forest', 'pine_tree', 'oak_tree', 'willow_tree', 'palm_tree', 'maple_tree']
# Cluster 4 (13 classes): ['clock', 'pear', 'apple', 'plate', 'bowl', 'can', 'bottle', 'cup', 'sweet_pepper', 'table', 'telephone', 'television', 'lamp']
# Cluster 3 (5 classes): ['sunflower', 'tulip', 'orchid', 'poppy', 'rose']
# Cluster 9 (4 classes): ['lobster', 'ray', 'flatfish', 'crab']
# Cluster 8 (1 classes): ['cloud']

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

def plot_kmeans(embeddings_dict, n_clusters=10, normalize=True, title="KMeans Clusters in 2D Space"):
    class_names = list(embeddings_dict.keys())
    class_encodings = torch.stack([embeddings_dict[cls] for cls in class_names])
    
    if normalize:
        class_encodings = torch.nn.functional.normalize(class_encodings, dim=1)

    # KMeans clustering
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    cluster_labels = kmeans.fit_predict(class_encodings.cpu().numpy())

    # Reduce to 2D
    #pca = PCA(n_components=2)
    #reduced = pca.fit_transform(class_encodings.cpu().numpy())
    reduced = TSNE(n_components=2).fit_transform(class_encodings.cpu().numpy())

    # Plot
    plt.figure(figsize=(10, 7))
    scatter = plt.scatter(reduced[:, 0], reduced[:, 1], c=cluster_labels, cmap='tab10', s=60)#, edgecolors='k')

    for i, name in enumerate(class_names):
        plt.text(reduced[i, 0], reduced[i, 1], name, fontsize=8, alpha=0.6)
    plt.title(title)
    plt.colorbar(scatter, label="Cluster ID")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    for cluster_id, names in sorted(clusters.items()):
        print(f"Cluster {cluster_id}: {', '.join(names)}")

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

def plot_selected_classes(embeddings_dict, selected_classes, normalize=True, title="Selected Class Embeddings (2D)"):
    # Filter embeddings
    filtered_names = [cls for cls in selected_classes if cls in embeddings_dict]
    if not filtered_names:
        print("No selected classes found in the dictionary.")
        return

    filtered_encodings = torch.stack([embeddings_dict[cls] for cls in filtered_names])

    if normalize:
        filtered_encodings = torch.nn.functional.normalize(filtered_encodings, dim=1)

    # Reduce to 2D using t-SNE
    reduced = TSNE(n_components=2, random_state=42).fit_transform(filtered_encodings.cpu().numpy())

    # Plot
    plt.figure(figsize=(8, 6))
    plt.scatter(reduced[:, 0], reduced[:, 1], s=100, c='royalblue')

    for i, name in enumerate(filtered_names):
        plt.text(reduced[i, 0], reduced[i, 1], name, fontsize=12, ha='center', va='center', color='white',
                 bbox=dict(facecolor='black', alpha=0.7, boxstyle='round,pad=0.3'))

    plt.title(title)
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
plot_kmeans(semantic)

# %%
from scipy.spatial.distance import cdist

def find_k_similar(embeddings_dict, k=5, metric='cosine'):
    class_names = list(embeddings_dict.keys())
    embeddings = torch.stack([embeddings_dict[cls] for cls in class_names])
    
    embeddings = torch.nn.functional.normalize(embeddings, dim=1)
    distances = cdist(embeddings.cpu().numpy(), embeddings.cpu().numpy(), metric=metric)
    
    top_k_dict = {}
    for i, cls in enumerate(class_names):
        sim_indices = np.argsort(distances[i]) 
        top_indices = [j for j in sim_indices if j != i][:k]  # exclude self
        top_k_dict[cls] = [class_names[j] for j in top_indices]

    return top_k_dict

# %%
similars_dict = find_k_similar(semantic)
similars_dict
# Out:
# {'apple': ['pear', 'flatfish', 'orange', 'plate', 'sweet_pepper'],
#  'aquarium_fish': ['turtle', 'trout', 'flatfish', 'bottle', 'plate'],
#  'bear': ['wolf', 'otter', 'fox', 'raccoon', 'porcupine'],
#  'bee': ['cockroach', 'butterfly', 'worm', 'beetle', 'caterpillar'],
#  'bottle': ['cup', 'bowl', 'table', 'tulip', 'cloud'],
#  'bowl': ['bottle', 'cup', 'tractor', 'plate', 'table'],
#  'boy': ['girl', 'man', 'woman', 'baby', 'table'],
#  'bridge': ['road', 'bus', 'motorcycle', 'mountain', 'house'],
#  'bus': ['tractor', 'train', 'road', 'motorcycle', 'pickup_truck'],
#  'can': ['cup', 'bottle', 'aquarium_fish', 'bed', 'bowl'],
#  'castle': ['skyscraper', 'house', 'mountain', 'bus', 'bowl'],
#  'caterpillar': ['butterfly', 'beetle', 'bee', 'porcupine', 'squirrel'],
#  'chair': ['couch', 'table', 'bed', 'motorcycle', 'clock'],
#  'clock': ['bed', 'television', 'table', 'house', 'mountain'],
#  'cloud': ['sea', 'mountain', 'lamp', 'bottle', 'clock'],
#  'cockroach': ['bee', 'raccoon', 'butterfly', 'worm', 'beetle'],
#  'couch': ['chair', 'bed', 'table', 'house', 'clock'],
#  'cup': ['bottle', 'bowl', 'table', 'house', 'can'],
#  'dinosaur': ['wolf', 'lizard', 'turtle', 'bear', 'raccoon'],
#  'dolphin': ['whale', 'shark', 'seal', 'turtle', 'shrew'],
#  'elephant': ['lizard', 'whale', 'dolphin', 'squirrel', 'mouse'],
#  'forest': ['plain', 'pine_tree', 'mountain', 'willow_tree', 'rose'],
#  'girl': ['boy', 'woman', 'man', 'baby', 'table'],
#  'hamster': ['shrew', 'squirrel', 'porcupine', 'mouse', 'lizard'],
#  'house': ['bed', 'plain', 'mountain', 'table', 'tractor'],
#  'kangaroo': ['possum', 'bear', 'squirrel', 'wolf', 'rabbit'],
#  'keyboard': ['telephone', 'television', 'train', 'table', 'tractor'],
#  'lawn_mower': ['tractor', 'motorcycle', 'poppy', 'plain', 'tulip'],
#  'lion': ['tiger', 'leopard', 'bear', 'fox', 'otter'],
#  'lizard': ['snake', 'turtle', 'squirrel', 'porcupine', 'butterfly'],
#  'lobster': ['shark', 'worm', 'bee', 'turtle', 'seal'],
#  'mountain': ['plain', 'sea', 'house', 'cloud', 'clock'],
#  'mouse': ['porcupine', 'squirrel', 'shrew', 'tulip', 'butterfly'],
#  'mushroom': ['worm', 'bee', 'turtle', 'shark', 'apple'],
#  'oak_tree': ['maple_tree', 'willow_tree', 'pine_tree', 'palm_tree', 'orange'],
#  'orange': ['apple', 'pear', 'sweet_pepper', 'orchid', 'tulip'],
#  'orchid': ['tulip', 'poppy', 'mouse', 'apple', 'palm_tree'],
#  'palm_tree': ['sweet_pepper', 'tulip', 'orchid', 'maple_tree', 'poppy'],
#  'pear': ['apple', 'orange', 'flatfish', 'sweet_pepper', 'orchid'],
#  'pine_tree': ['oak_tree', 'forest', 'squirrel', 'willow_tree', 'palm_tree'],
#  'plate': ['apple', 'flatfish', 'table', 'clock', 'bed'],
#  'porcupine': ['squirrel', 'mouse', 'shrew', 'lizard', 'leopard'],
#  'possum': ['squirrel', 'kangaroo', 'mouse', 'leopard', 'bear'],
#  'rabbit': ['mouse', 'hamster', 'fox', 'wolf', 'kangaroo'],
#  'raccoon': ['wolf', 'bear', 'skunk', 'cockroach', 'fox'],
#  'ray': ['shark', 'beaver', 'crab', 'dolphin', 'crocodile'],
#  'road': ['bus', 'bridge', 'plain', 'mountain', 'man'],
#  'seal': ['whale', 'dolphin', 'shark', 'turtle', 'wolf'],
#  'shrew': ['squirrel', 'porcupine', 'fox', 'mouse', 'skunk'],
#  'skunk': ['raccoon', 'shrew', 'fox', 'lizard', 'mouse'],
#  'skyscraper': ['castle', 'house', 'mountain', 'clock', 'wardrobe'],
#  'snake': ['lizard', 'turtle', 'shark', 'worm', 'dinosaur'],
#  'spider': ['butterfly', 'lizard', 'beetle', 'crab', 'caterpillar'],
#  'squirrel': ['porcupine', 'possum', 'mouse', 'shrew', 'lizard'],
#  'streetcar': ['bicycle', 'tractor', 'rocket', 'motorcycle', 'bus'],
#  'sunflower': ['tulip', 'poppy', 'orange', 'orchid', 'palm_tree'],
#  'tank': ['tractor', 'streetcar', 'pickup_truck', 'bicycle', 'bus'],
#  'tiger': ['leopard', 'lion', 'fox', 'squirrel', 'bear'],
#  'train': ['bus', 'streetcar', 'tractor', 'pickup_truck', 'keyboard'],
#  'trout': ['flatfish', 'shark', 'turtle', 'aquarium_fish', 'lobster'],
#  'tulip': ['poppy', 'orchid', 'sweet_pepper', 'mouse', 'rose'],
#  'turtle': ['lizard', 'worm', 'shark', 'trout', 'snake'],
#  'willow_tree': ['maple_tree', 'rose', 'oak_tree', 'tulip', 'poppy'],
#  'wolf': ['bear', 'raccoon', 'fox', 'dinosaur', 'leopard'],
#  'beaver': ['lizard', 'ray', 'otter', 'turtle', 'squirrel'],
#  'beetle': ['butterfly', 'caterpillar', 'bee', 'lizard', 'porcupine'],
#  'butterfly': ['caterpillar', 'beetle', 'bee', 'lizard', 'mouse'],
#  'camel': ['shrew', 'fox', 'crab', 'hamster', 'beaver'],
#  'cattle': ['mouse', 'house', 'porcupine', 'leopard', 'bee'],
#  'crab': ['lizard', 'butterfly', 'spider', 'beetle', 'ray'],
#  'crocodile': ['turtle', 'beaver', 'lizard', 'shark', 'ray'],
#  'fox': ['bear', 'shrew', 'otter', 'wolf', 'squirrel'],
#  'lamp': ['cloud', 'television', 'bed', 'clock', 'raccoon'],
#  'leopard': ['tiger', 'lion', 'squirrel', 'porcupine', 'bear'],
#  'man': ['woman', 'boy', 'girl', 'baby', 'mountain'],
#  'maple_tree': ['willow_tree', 'oak_tree', 'tulip', 'rose', 'palm_tree'],
#  'motorcycle': ['bicycle', 'tractor', 'streetcar', 'pickup_truck', 'bus'],
#  'plain': ['mountain', 'house', 'forest', 'road', 'sea'],
#  'poppy': ['tulip', 'orchid', 'rose', 'sweet_pepper', 'butterfly'],
#  'rose': ['poppy', 'willow_tree', 'tulip', 'maple_tree', 'orchid'],
#  'table': ['bed', 'couch', 'wardrobe', 'bottle', 'chair'],
#  'tractor': ['bicycle', 'motorcycle', 'streetcar', 'pickup_truck', 'bus'],
#  'woman': ['man', 'girl', 'boy', 'cup', 'baby'],
#  'baby': ['boy', 'girl', 'apple', 'man', 'house'],
#  'bed': ['couch', 'table', 'house', 'clock', 'wardrobe'],
#  'bicycle': ['tractor', 'streetcar', 'motorcycle', 'bus', 'pickup_truck'],
#  'chimpanzee': ['leopard', 'raccoon', 'possum', 'squirrel', 'dinosaur'],
#  'flatfish': ['apple', 'trout', 'shark', 'plate', 'tulip'],
#  'otter': ['bear', 'fox', 'squirrel', 'beaver', 'shrew'],
#  'pickup_truck': ['tractor', 'motorcycle', 'bus', 'bicycle', 'streetcar'],
#  'rocket': ['streetcar', 'tractor', 'bicycle', 'motorcycle', 'bus'],
#  'sea': ['cloud', 'mountain', 'plain', 'flatfish', 'bottle'],
#  'shark': ['ray', 'worm', 'lobster', 'dolphin', 'trout'],
#  'snail': ['turtle', 'shark', 'caterpillar', 'butterfly', 'lizard'],
#  'sweet_pepper': ['tulip', 'poppy', 'palm_tree', 'apple', 'orchid'],
#  'telephone': ['television', 'butterfly', 'mouse', 'plate', 'table'],
#  'television': ['telephone', 'clock', 'bed', 'lamp', 'table'],
#  'wardrobe': ['table', 'bed', 'house', 'bottle', 'cup'],
#  'whale': ['dolphin', 'seal', 'turtle', 'shark', 'ray'],
#  'worm': ['shark', 'bee', 'turtle', 'lobster', 'mouse']}

# %%
with open("most_confused.json", "w") as f:
    json.dump(similars_dict, f, indent=2)

# %%
def study_semantics(semantic, title):
    class_names = list(semantic.keys())
    embeddings = torch.stack([semantic[cls] for cls in class_names])
    print(f"Interclass entropy: {interclass_entropy(embeddings)}")
    print(f"Histogram interclass entropy: {interclass_entropy_histogram(embeddings)}")
    plot_kmeans(semantic, title=title)
    analyze_class_distances(semantic, show=False)

# %%
# Default

default_path = "/Users/jdieguez/Documents/master/TFM/code/TFM-SemFew/Model/semantic/cifar100_semantic_clip_gpt.pth"
semantic = torch.load(default_path, map_location=DEVICE)['semantic_feature']
semantic = {k: v.float() for k, v in semantic.items()}

study_semantics(semantic, "Default")
# Out:
# Interclass entropy: 8.46810501578651
# Histogram interclass entropy: 4.92467459531826
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.0202
#  * Max distance:  0.2911
#  * Mean distance: 0.1453
# 🔍 Top k Most Similar Classes:
#  - girl ↔ woman: 0.0202
#  - dolphin ↔ whale: 0.0368
#  - snake ↔ lizard: 0.0373
#  - man ↔ woman: 0.0391
#  - wolf ↔ fox: 0.0404
#  - squirrel ↔ hamster: 0.0408
#  - bear ↔ hamster: 0.0413
#  - bear ↔ rabbit: 0.0422
#  - bus ↔ streetcar: 0.0425
#  - bear ↔ cattle: 0.0429

# %%
# With names
class_names = ['apple', 'aquarium_fish', 'bear', 'bee', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'can', 'castle', 'caterpillar', 'chair', 'clock', 'cloud', 'cockroach', 'couch', 'cup', 'dinosaur', 'dolphin', 'elephant', 'forest', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard', 'lawn_mower', 'lion', 'lizard', 'lobster', 'mountain', 'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid', 'palm_tree', 'pear', 'pine_tree', 'plate', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 'seal', 'shrew', 'skunk', 'skyscraper', 'snake', 'spider', 'squirrel', 'streetcar', 'sunflower', 'tank', 'tiger', 'train', 'trout', 'tulip', 'turtle', 'willow_tree', 'wolf', 'beaver', 'beetle', 'butterfly', 'camel', 'cattle', 'crab', 'crocodile', 'flatfish', 'lamp', 'maple_tree', 'motorcycle', 'otter', 'sea', 'shark', 'television', 'tractor', 'baby', 'bed', 'bicycle', 'chimpanzee', 'fox', 'leopard', 'man', 'pickup_truck', 'plain', 'poppy', 'rocket', 'rose', 'snail', 'sweet_pepper', 'table', 'telephone', 'wardrobe', 'whale', 'woman', 'worm']
class_descriptions = {cls:cls for cls in class_names}
semantic = encode_descriptions(class_descriptions)
study_semantics(semantic, "Just names")
# Out:
# Interclass entropy: 8.477072437739844
# Histogram interclass entropy: 4.9770559557881855
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.0958
#  * Max distance:  0.6316
#  * Mean distance: 0.3428
# 🔍 Top k Most Similar Classes:
#  - man ↔ plain: 0.0958
#  - boy ↔ girl: 0.1032
#  - boy ↔ man: 0.1043
#  - cloud ↔ mountain: 0.1054
#  - mountain ↔ man: 0.1055
#  - boy ↔ ray: 0.1097
#  - bear ↔ man: 0.1119
#  - boy ↔ baby: 0.1125
#  - girl ↔ baby: 0.1131
#  - sea ↔ man: 0.1168

# %%
def study_from_file(file, title):
    with open(file, 'r') as f:
        cds = json.load(f)
    semantic = encode_descriptions(cds)
    
    study_semantics(semantic, title)

# %%
# Wordnet descriptions

study_from_file("wn_descriptions.json", "WordNet embeddings")
# Out:
# Interclass entropy: 8.491220921652165
# Histogram interclass entropy: 4.719907369958058
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.0593
#  * Max distance:  0.6266
#  * Mean distance: 0.4226
# 🔍 Top k Most Similar Classes:
#  - man ↔ woman: 0.0593
#  - tiger ↔ leopard: 0.0753
#  - tulip ↔ poppy: 0.0788
#  - boy ↔ girl: 0.1003
#  - tractor ↔ bicycle: 0.1583
#  - streetcar ↔ bicycle: 0.1602
#  - motorcycle ↔ bicycle: 0.1606
#  - motorcycle ↔ tractor: 0.1620
#  - caterpillar ↔ butterfly: 0.1660
#  - apple ↔ pear: 0.1687

# %%
study_from_file("gpt_descriptions.json", "GPT embeddings")
# Out:
# Interclass entropy: 8.482092754571214
# Histogram interclass entropy: 4.948115330464122
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.0743
#  * Max distance:  0.6458
#  * Mean distance: 0.3957
# 🔍 Top k Most Similar Classes:
#  - hamster ↔ mouse: 0.0743
#  - hamster ↔ squirrel: 0.0743
#  - mouse ↔ squirrel: 0.0775
#  - lobster ↔ crab: 0.0915
#  - bear ↔ camel: 0.1046
#  - rabbit ↔ shrew: 0.1050
#  - boy ↔ man: 0.1064
#  - mouse ↔ rabbit: 0.1156
#  - hamster ↔ rabbit: 0.1162
#  - kangaroo ↔ possum: 0.1195

# %%
study_from_file("groq_img_descriptions.json", "groq_img_descriptions")
# Out:
# Interclass entropy: 8.488234371164541
# Histogram interclass entropy: 4.862796313340406
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.1355
#  * Max distance:  0.6708
#  * Mean distance: 0.3936
# 🔍 Top k Most Similar Classes:
#  - lobster ↔ crab: 0.1355
#  - palm_tree ↔ pine_tree: 0.1449
#  - shark ↔ whale: 0.1474
#  - trout ↔ shark: 0.1540
#  - mouse ↔ shrew: 0.1579
#  - boy ↔ man: 0.1622
#  - bear ↔ beaver: 0.1711
#  - bee ↔ spider: 0.1720
#  - bowl ↔ cup: 0.1720
#  - mouse ↔ fox: 0.1723

# %%
study_from_file("gemini_img_descriptions.json", "gemini_img_descriptions")
# Out:
# Interclass entropy: 8.48266384782966
# Histogram interclass entropy: 4.701767839253125
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.1280
#  * Max distance:  0.7810
#  * Mean distance: 0.3842
# 🔍 Top k Most Similar Classes:
#  - dolphin ↔ whale: 0.1280
#  - tractor ↔ pickup_truck: 0.1434
#  - chair ↔ table: 0.1449
#  - motorcycle ↔ bicycle: 0.1492
#  - wolf ↔ fox: 0.1494
#  - lizard ↔ snake: 0.1533
#  - rabbit ↔ squirrel: 0.1540
#  - chair ↔ couch: 0.1570
#  - lion ↔ tiger: 0.1590
#  - spider ↔ beetle: 0.1622

# %%
study_from_file("gemini_text_descriptions.json", "gemini_text_descriptions")
# Out:
# Interclass entropy: 8.485353408236945
# Histogram interclass entropy: 4.888673318110951
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.1300
#  * Max distance:  0.6940
#  * Mean distance: 0.3947
# 🔍 Top k Most Similar Classes:
#  - lion ↔ tiger: 0.1300
#  - mouse ↔ squirrel: 0.1366
#  - motorcycle ↔ bicycle: 0.1368
#  - lobster ↔ crab: 0.1378
#  - lion ↔ leopard: 0.1482
#  - bowl ↔ cup: 0.1531
#  - palm_tree ↔ pine_tree: 0.1537
#  - tiger ↔ leopard: 0.1538
#  - wolf ↔ fox: 0.1566
#  - hamster ↔ mouse: 0.1569

# %%
study_from_file("groq_prompt0.json", "groq_prompt0")
# Out:
# Interclass entropy: 8.4873647393041
# Histogram interclass entropy: 4.875693571195437
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.1180
#  * Max distance:  0.6149
#  * Mean distance: 0.3595
# 🔍 Top k Most Similar Classes:
#  - couch ↔ bed: 0.1180
#  - boy ↔ girl: 0.1190
#  - chair ↔ table: 0.1235
#  - chair ↔ couch: 0.1310
#  - girl ↔ woman: 0.1315
#  - mountain ↔ plain: 0.1375
#  - palm_tree ↔ pine_tree: 0.1420
#  - bowl ↔ cup: 0.1478
#  - dolphin ↔ whale: 0.1480
#  - motorcycle ↔ bicycle: 0.1491

# %%
study_from_file("groq_prompt1.json", "groq_prompt1")
# Out:
# Interclass entropy: 8.486669277052979
# Histogram interclass entropy: 4.975320557099978
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.1073
#  * Max distance:  0.5728
#  * Mean distance: 0.3586
# 🔍 Top k Most Similar Classes:
#  - girl ↔ woman: 0.1073
#  - boy ↔ man: 0.1198
#  - bear ↔ rabbit: 0.1272
#  - boy ↔ baby: 0.1300
#  - man ↔ woman: 0.1373
#  - girl ↔ baby: 0.1381
#  - lizard ↔ snake: 0.1385
#  - boy ↔ girl: 0.1397
#  - mouse ↔ squirrel: 0.1402
#  - boy ↔ woman: 0.1444

# %%
study_from_file("groq_prompt2.json", "groq_prompt2")
# Out:
# Interclass entropy: 8.488848999645661
# Histogram interclass entropy: 4.749045875853667
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.0924
#  * Max distance:  0.5834
#  * Mean distance: 0.3423
# 🔍 Top k Most Similar Classes:
#  - girl ↔ woman: 0.0924
#  - man ↔ woman: 0.1135
#  - couch ↔ bed: 0.1180
#  - boy ↔ man: 0.1189
#  - motorcycle ↔ bicycle: 0.1201
#  - bowl ↔ cup: 0.1285
#  - shark ↔ whale: 0.1296
#  - chair ↔ couch: 0.1326
#  - dolphin ↔ whale: 0.1346
#  - girl ↔ man: 0.1347

# %%
study_from_file("groq_prompt3.json", "groq_prompt3")
# Out:
# Interclass entropy: 8.487555702898089
# Histogram interclass entropy: 4.8819239972909525
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.1084
#  * Max distance:  0.6154
#  * Mean distance: 0.3719
# 🔍 Top k Most Similar Classes:
#  - girl ↔ woman: 0.1084
#  - bear ↔ rabbit: 0.1393
#  - man ↔ woman: 0.1413
#  - boy ↔ man: 0.1416
#  - bear ↔ wolf: 0.1456
#  - bear ↔ cattle: 0.1488
#  - oak_tree ↔ maple_tree: 0.1496
#  - bottle ↔ cup: 0.1510
#  - boy ↔ girl: 0.1517
#  - wolf ↔ fox: 0.1524

# %%
study_from_file("gemini_prompt3.json", "gemini_prompt3")
# Out:
# Interclass entropy: 8.485736402700434
# Histogram interclass entropy: 4.85112881173244
# Cluster 0: raccoon, girl, elephant, mushroom, possum, squirrel, wolf, mouse, boy, shrew, tiger, lion, bear, porcupine, hamster, snake, skunk, lizard, kangaroo, dinosaur, rabbit, baby, chimpanzee, fox, leopard, man, woman, camel, cattle
# Cluster 1: skyscraper, castle, keyboard, tank, road, couch, lawn_mower, bridge, mountain, house, bed, plain, rocket, wardrobe, motorcycle
# Cluster 2: train, bus, chair, streetcar, bicycle, pickup_truck, tractor
# Cluster 3: sunflower, tulip, orchid, poppy, rose
# Cluster 4: clock, pear, apple, plate, bowl, can, bottle, cup, sweet_pepper, table, telephone, television, lamp
# Cluster 5: spider, caterpillar, cockroach, bee, snail, worm, butterfly, beetle
# Cluster 6: turtle, seal, dolphin, trout, whale, otter, crocodile, shark, beaver, sea, aquarium_fish
# Cluster 7: orange, forest, pine_tree, oak_tree, willow_tree, palm_tree, maple_tree
# Cluster 8: cloud
# Cluster 9: lobster, ray, flatfish, crab
#  * Min distance:  0.1128
#  * Max distance:  0.6663
#  * Mean distance: 0.3818
# 🔍 Top k Most Similar Classes:
#  - bowl ↔ cup: 0.1128
#  - raccoon ↔ wolf: 0.1181
#  - chair ↔ couch: 0.1218
#  - bear ↔ wolf: 0.1335
#  - tulip ↔ poppy: 0.1420
#  - bottle ↔ cup: 0.1420
#  - motorcycle ↔ bicycle: 0.1434
#  - lion ↔ tiger: 0.1435
#  - lizard ↔ snake: 0.1447
#  - couch ↔ bed: 0.1447
